# %%
# %pylab
from IPython.display import clear_output
import numpy as np
import sys
import scipy as sp
from scipy import optimize

import time
import os

from sklearn import ensemble
import cv2

import scipy.io as sio
import glob
import commands
import shutil, errno

from PIL import Image

import pycuda.autoinit
import pycuda.driver as drv
import pycuda.gpuarray as gpuarray

cudaFolder = "/home/ilisescu/PhD/cuda/"

import GraphWithValues as gwv
import VideoTexturesUtils as vtu

import ComputeGridFeatures as cgf

DICT_SEQUENCE_NAME = 'semantic_sequence_name'
DICT_BBOXES = 'bboxes'
DICT_FOOTPRINTS = 'footprints' ## same as bboxes but it indicates the footprint of the sprite on the ground plane
DICT_BBOX_ROTATIONS = 'bbox_rotations'
DICT_BBOX_CENTERS = 'bbox_centers'
DICT_FRAMES_LOCATIONS = 'frame_locs'
DICT_MASK_LOCATION = 'frame_masks_location'
DICT_SEQUENCE_FRAMES = 'sequence_frames'
DICT_SEQUENCE_IDX = 'semantic_sequence_idx' # index of the instantiated sem sequence in the list of all used sem sequences for a synthesised sequence
DICT_DESIRED_SEMANTICS = 'desired_semantics' # stores what the desired semantics are for a certain sprite 
#(I could index them by the frame when the toggle happened instead of using the below but maybe ordering is important and I would lose that using a dict)
DICT_FRAME_SEMANTIC_TOGGLE = 'frame_semantic_toggle'# stores the frame index in the generated sequence when the desired semantics have changed
DICT_ICON_TOP_LEFT = "icon_top_left"
DICT_ICON_FRAME_KEY = "icon_frame_key"
DICT_ICON_SIZE = "icon_size"
DICT_REPRESENTATIVE_COLOR = 'representative_color'
DICT_OFFSET = "instance_offset"
DICT_SCALE = "instance_scale"
DICT_FRAME_SEMANTICS = "semantics_per_frame"
DICT_USED_SEQUENCES = "used_semantic_sequences"
DICT_SEQUENCE_INSTANCES = "sequence_instances"
DICT_SEQUENCE_BG = "sequence_background_image"
DICT_SEQUENCE_LOCATION = "sequence_location"
DICT_PATCHES_LOCATION = "sequence_preloaded_patches_location"
DICT_TRANSITION_COSTS_LOCATION = "sequence_precomputed_transition_costs_location"

def copyanything(src, dst):
    try:
        shutil.copytree(src, dst)
    except OSError as exc: # python >2.5
        if exc.errno == errno.ENOTDIR:
            shutil.copy(src, dst)
        else: raise
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# dataPath = "/home/ilisescu/PhD/data/"
dataPath = "/media/ilisescu/Data1/PhD/data/"

# dataSet = "pendulum/"
# dataSet = "tree/"
# dataSet = "splashes_water/"
# dataSet = "small_waterfall/"
# dataSet = "sisi_flag/"
# dataSet = "eu_flag_ph_left/"
# dataSet = "ribbon2/"
# dataSet = "candle1/segmentedAndCropped/"
# dataSet = "wave3/"
dataSet = "wave2/"
# dataSet = "wave1/"
framePaths = np.sort(glob.glob(dataPath + dataSet + "frame*.png"))
numFrames = len(framePaths)
print numFrames
imageSize = np.array(Image.open(framePaths[0])).shape[0:2]
# Out:
# 3408

# %%
def loadSequenceData(framePaths, resizeRatio, doRGB, temporalRange = None, doNormalize = True) :
    
    baseDimensionality = int(np.prod(np.round(np.array(imageSize)*resizeRatio)))
    if temporalRange != None :
        rangeResizeRatios = resizeRatio/2**np.abs(arange(-np.floor(len(temporalRange)/2), np.floor(len(temporalRange)/2)+1))
    
    numChannels = np.array([1, 3])
    
    if temporalRange != None :
        sequenceData = np.zeros((np.sum(baseDimensionality/((resizeRatio/rangeResizeRatios)**2))*numChannels[int(doRGB)], numFrames), dtype=np.float32)
    else :
        sequenceData = np.zeros((baseDimensionality*numChannels[int(doRGB)], numFrames), dtype=np.float32)
        
    for i in xrange(len(framePaths)) :
        if temporalRange != None :
            feats = np.empty(0)
            for delta, ratio in zip(temporalRange, rangeResizeRatios) :
                if delta+i >= 0 and delta+i < numFrames :
                    feats = np.concatenate((feats, 
                                            np.ndarray.flatten(np.array(cv2.cvtColor(cv2.resize(cv2.imread(framePaths[delta+i]), 
                                                                                                (0, 0), fx=ratio, fy=ratio, 
                                                                                                interpolation=cv2.INTER_AREA), cv2.COLOR_BGR2GRAY)))))
                else :
                    feats = np.concatenate((feats, np.zeros(baseDimensionality/((resizeRatio/ratio)**2))))
            sequenceData[:, i] = feats
        else :
            sequenceData[:, i] = np.ndarray.flatten(np.array(cv2.cvtColor(cv2.resize(cv2.imread(framePaths[i]), 
                                                                                     (0, 0), fx=resizeRatio, fy=resizeRatio,
                                                                                     interpolation=cv2.INTER_AREA), cv2.COLOR_BGR2GRAY)))

        sys.stdout.write('\r' + "Loaded image " + np.string_(i) + " of " + np.string_(numFrames))
        sys.stdout.flush()
    
    if doNormalize :
        sequenceData /= np.float32(255)
        
    clear_output()
    print "loaded", sequenceData.shape[-1], "frames with", numChannels[int(doRGB)], "channels ( D =", sequenceData.shape[0], ")"
    
    return sequenceData

resizeRatio = 1.0#0.4#0.5#0.75
doRGB = False
temporalRange = np.array([-2, -1, 0, 1, 2])
# temporalRange = np.array([-1, 0, 1])

# sequenceData = loadSequenceData(framePaths, resizeRatio, doRGB)

# %%
useValidatedJumps = True

def getTrainingExamples(dataLoc, numFrames, useValidatedJumps, useRandomBads, numBadExamples = 1000, minIdxsDiff = 10, verbose = True) :
    ## get feats of subsequent frames
    goodPairsIdxs = np.array([np.arange(numFrames-1, dtype=int), np.arange(1, numFrames, dtype=int)])
    if verbose : print "added", goodPairsIdxs.shape[-1], "subsequent pairs as GOOD PAIRS"
    badPairsIdxs = np.empty((2, 0), dtype=int)


    if useValidatedJumps and os.path.isfile(dataLoc+"validatedJumps.npy") :
        ## validatedJumps has indices of good jumps which means that it contains indices of distances between i and j+1
        ## so need to take (j+1)-1 to get indices of pairs whos distance has been labelled
        validatedJumps = np.load(dataLoc+"validatedJumps.npy")

        additionalGoodPairsIdxs = np.argwhere(validatedJumps == 1).T
        if additionalGoodPairsIdxs.shape[-1] > 0 :
            goodPairsIdxs = np.concatenate((goodPairsIdxs, additionalGoodPairsIdxs), axis=1)
            if verbose : print "added", additionalGoodPairsIdxs.shape[-1], "validated pairs as GOOD PAIRS"
        
        additionalBadPairsIdxs = np.argwhere(validatedJumps == 0).T
        if additionalBadPairsIdxs.shape[-1] > 0 :
            badPairsIdxs = np.concatenate((badPairsIdxs, additionalBadPairsIdxs), axis=1)
            if verbose : print "added", additionalBadPairsIdxs.shape[-1], "validated pairs as BAD PAIRS"
            
    if useRandomBads :
        ## get feats of random pairings that are considered bad
        additionalBadPairsIdxs = np.sort(np.array([np.random.choice(np.arange(numFrames), numBadExamples),
                                                   np.random.choice(np.arange(numFrames), numBadExamples)]), axis=0)

        if verbose : print len(np.argwhere(np.abs(additionalBadPairsIdxs[0, :]-additionalBadPairsIdxs[1, :]) < minIdxsDiff)), "invalid random pairs"
        for pairIdx in xrange(numBadExamples) :
            idxDiff = np.abs(additionalBadPairsIdxs[0, pairIdx] - additionalBadPairsIdxs[1, pairIdx])
            tmp = idxDiff
            newPair = additionalBadPairsIdxs[:, pairIdx]
            while idxDiff < minIdxsDiff :
                newPair = np.sort(np.random.choice(np.arange(numFrames), 2))
                idxDiff = np.abs(newPair[0] - newPair[1])
        #     print badPairsIdxs[:, pairIdx], newPair, tmp
            additionalBadPairsIdxs[:, pairIdx] = newPair
        #     if badPairsIdxs[pairIdx, 0] - badPairsIdxs[pairIdx, 1] < minIdxsDiff

        # print badPairsIdxs.T
        if verbose : print len(np.argwhere(np.abs(additionalBadPairsIdxs[0, :]-additionalBadPairsIdxs[1, :]) < minIdxsDiff)), "invalid random pairs"
        if additionalBadPairsIdxs.shape[-1] > 0 :
            badPairsIdxs = np.concatenate((badPairsIdxs, additionalBadPairsIdxs), axis=1)
            if verbose : print "added", additionalBadPairsIdxs.shape[-1], "random pairs as BAD PAIRS"
    
    if verbose : print
    print goodPairsIdxs.shape[-1], "GOOD PAIRS and", badPairsIdxs.shape[-1], "BAD PAIRS total"
    
    
    return goodPairsIdxs, badPairsIdxs
        
goodPairsIdxs, badPairsIdxs = getTrainingExamples(dataPath+dataSet, numFrames, useValidatedJumps, True, verbose=False)
# Out:
# 3407 GOOD PAIRS and 1000 BAD PAIRS total

# %%
def getPairFeats(frame1, frame2, imageSize, framePaths, frame1PatchesLocs, frame2PatchesLocs, displacePatchSize, gridStencils,
                 usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid, k = 1.0, L = 10.0) :
    
    feats = np.empty(0)
    
    if usePatchDisplace :
        frame1Tmp = frame1/255.0
        frame2Tmp = frame2/255.0
        feats = np.concatenate((feats, np.array([np.sqrt(np.sum((frame2Tmp[l2[0]:l2[0]+displacePatchSize[0], l2[1]:l2[1]+displacePatchSize[1], :]-
                                                                 frame1Tmp[l1[0]:l1[0]+displacePatchSize[0], l1[1]:l1[1]+displacePatchSize[1], :])**2)) 
                                                 for l2, l1 in zip(frame2PatchesLocs, frame1PatchesLocs)])))
    if frame1.shape[-1] == 4 :
        frame1 = cv2.cvtColor(frame1, cv2.COLOR_RGBA2GRAY)
    else :
        frame1 = cv2.cvtColor(frame1, cv2.COLOR_RGB2GRAY)
        
    if frame2.shape[-1] == 4 :
        frame2 = cv2.cvtColor(frame2, cv2.COLOR_RGBA2GRAY)
    else :
        frame2 = cv2.cvtColor(frame2, cv2.COLOR_RGB2GRAY)

    if useFlow :
        flow = np.array(cv2.calcOpticalFlowFarneback(frame1, frame2, 0.5, 3, 15, 3, 5, 1.1, 0), np.float64)
        ## sigmoid
        if useSigmoid :
            flow = L/(1.0+np.exp(-k*flow))

    for j, stencil in enumerate(gridStencils) :
        ## add SSD to feature vector
        if useSSD :
            feats = np.concatenate((feats, [np.average((frame1[stencil]/255.0-frame2[stencil]/255.0)**2)]))
        ## add average flow intensity
        if useFlow :
            feats = np.concatenate((feats, [np.average(np.linalg.norm(np.array([flow[:, :, 0][stencil], flow[:, :, 1][stencil]]), axis=0))]))

        ## add augmentation to x
        if useAugment :
            feats = np.concatenate((feats, [np.average(((255.0-frame1[stencil])/255.0-frame2[stencil]/255.0)**2+
                                                       ((255.0-frame2[stencil])/255.0-frame1[stencil]/255.0)**2)]))
            
    return feats

# %%
def getPairFeatsData(displacePatchSize, displaceSpacing, dirDisplacements, imageSize, pairsIdxs, gridSize, framePaths,
                     usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid, subPatchTopLeft=np.array([0, 0])) :

    displacements = np.concatenate((np.array([np.zeros(len(dirDisplacements)), dirDisplacements], int), ## EAST
                          np.array([dirDisplacements, dirDisplacements], int), ## SOUT-EAST
                          np.array([dirDisplacements, np.zeros(len(dirDisplacements))], int), ## SOUTH
                          np.array([dirDisplacements, -dirDisplacements], int), ## SOUTH-WEST
                          np.array([np.zeros(len(dirDisplacements)), -dirDisplacements], int), ## WEST
                          np.array([-dirDisplacements, -dirDisplacements], int), ## NORTH-WEST
                          np.array([-dirDisplacements, np.zeros(len(dirDisplacements))], int), ## NORTH
                          np.array([-dirDisplacements, dirDisplacements], int), ## NORTH-EAST
                          ), axis=-1)

    patchYs = np.arange(np.max(displacements), imageSize[0]-displacePatchSize[0]-np.max(displacements), displaceSpacing)
    patchYs = patchYs.reshape((1, len(patchYs)))
    patchXs = np.arange(np.max(displacements), imageSize[1]-displacePatchSize[1]-np.max(displacements), displaceSpacing)
    patchXs = patchXs.reshape((1, len(patchXs)))
    patchLocations = np.array(np.concatenate((patchYs.repeat(len(patchXs.T)),
                                              patchXs.repeat(len(patchYs.T), axis=0).flatten())).reshape((2, len(patchXs.T)*len(patchYs.T))), int)

    frame1Idxs = np.empty((0, 2), dtype=int)
    frame2Idxs = np.empty((0, 2), dtype=int)
    for i, locSlice in enumerate(np.arange(patchXs.shape[-1], patchLocations.shape[-1]+1, patchXs.shape[-1])) :
        frame1Idxs = np.concatenate((frame1Idxs, np.repeat(patchLocations[:, locSlice-patchXs.shape[-1]:locSlice], len(displacements.T), axis=1).T), axis=0)
        frame2Idxs = np.concatenate((frame2Idxs, np.array([disp + loc for loc in patchLocations[:, locSlice-patchXs.shape[-1]:locSlice].T for disp in displacements.T])), axis=0)

    stencils2D = cgf.stencil2D(gridSize[0], gridSize[1], [imageSize[0], imageSize[1], 3])
    
#     displacePatchSize = displacePatchSize/2
    
    featsData = []
    avgTime = 0.0
    for j, pair in enumerate(pairsIdxs.T) :
        t = time.time()
        
        frame1 = np.array(Image.open(framePaths[pair[0]]))[subPatchTopLeft[0]:subPatchTopLeft[0]+imageSize[0], subPatchTopLeft[1]:subPatchTopLeft[1]+imageSize[1], :]
        frame2 = np.array(Image.open(framePaths[pair[1]]))[subPatchTopLeft[0]:subPatchTopLeft[0]+imageSize[0], subPatchTopLeft[1]:subPatchTopLeft[1]+imageSize[1], :]
        
        featsData.append(getPairFeats(frame1, frame2, imageSize, framePaths, frame1Idxs, frame2Idxs, displacePatchSize, stencils2D,
                                      usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid))

        avgTime = (avgTime*j + time.time()-t)/(j+1)
        remainingTime = avgTime*(len(pairsIdxs.T)-j-1)/60.0
        sys.stdout.write('\r' + "Done pair " + np.string_(j) + " of " + np.string_(len(pairsIdxs.T)) +
                         " (avg time: " + np.string_(avgTime) + " secs --- remaining: " +
                         np.string_(int(np.floor(remainingTime))) + ":" + np.string_(int((remainingTime - np.floor(remainingTime))*60)) + ")")
        sys.stdout.flush()
        
    return featsData#, frame1Idxs, frame2Idxs

patchSize = np.array([32, 32], int)
spacing = 32.0 ## how far away a patch is from the previous one

dirDisplacements = np.array([1, 2, 4, 8, 16])
gridSize = np.array((10, 10))

usePatchDisplace = True
useSSD = False
useFlow = False
useAugment = False
useSigmoid = False

# goodExamplesData = getPairFeatsData(patchSize, spacing, dirDisplacements, imageSize, goodPairsIdxs, gridSize, framePaths,
#                                     usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid)

# badExamplesData = getPairFeatsData(patchSize, spacing, dirDisplacements, imageSize, badPairsIdxs, gridSize, framePaths,
#                                    usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid)

# %%
badExamplesData, frame1Idxs, frame2Idxs = getPairFeatsData(patchSize, spacing, dirDisplacements, imageSize, badPairsIdxs[:, 0:1], 
                                                            np.array((10, 10)), framePaths, usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid)
# Out:
# Done pair 0 of 1 (avg time: 0.775813102722 secs --- remaining: 0:0)

# %%
## load a given semantic sequence
tmpFolder = "/home/ilisescu/"        
sequence = np.load(dataPath+dataSet+"semantic_sequence-tara2.npy").item()
tmpLoc = tmpFolder+"".join(sequence[DICT_MASK_LOCATION].split("/")[-2])+"/"
print "starting", sequence[DICT_SEQUENCE_NAME]; sys.stdout.flush()

t = time.time()
if not os.path.isdir(tmpLoc) :
    copyanything(sequence[DICT_MASK_LOCATION], tmpLoc)
    print "copied folder to", tmpLoc; sys.stdout.flush()
else :
    print tmpLoc, "already exists"; sys.stdout.flush()

## compute bounding box
    
topLeft = np.array([720, 1280])
bottomRight = np.array([0, 0])
for i, key in enumerate(np.sort(sequence[DICT_BBOXES].keys())) :
    alpha = np.array(Image.open(tmpLoc+"frame-{0:05d}.png".format(key+1)))[:, :, -1]
    vis = np.argwhere(alpha != 0)
    tl = np.min(vis, axis=0)
    topLeft[0] = np.min([topLeft[0], tl[0]])
    topLeft[1] = np.min([topLeft[1], tl[1]])

    br = np.max(vis, axis=0)
    bottomRight[0] = np.max([bottomRight[0], br[0]])
    bottomRight[1] = np.max([bottomRight[1], br[1]])

    sys.stdout.write('\r' + "Frames " + np.string_(i) + " of " + np.string_(len(sequence[DICT_BBOXES])) + " done")
    sys.stdout.flush()
print
print "computed bbox", topLeft, bottomRight, "need", np.prod(bottomRight-topLeft)*3*8/1000000.0*len(sequence[DICT_BBOXES]), "MBs"; sys.stdout.flush()

numFrames = len(sequence[DICT_BBOXES])

bgPatch = np.array(Image.open(dataPath+dataSet+"median.png"))[topLeft[0]:bottomRight[0], topLeft[1]:bottomRight[1], 0:3]/255.0

## load floating point pixel data

paddedFrames = np.zeros(np.hstack([numFrames, np.prod((bottomRight[0]-topLeft[0], bottomRight[1]-topLeft[1])), 4]), dtype=np.float32)
for idx, key in enumerate(np.sort(sequence[DICT_BBOXES].keys())) :
    img = np.array(Image.open(tmpLoc+"frame-{0:05d}.png".format(key+1)), dtype=np.float32)[topLeft[0]:bottomRight[0], topLeft[1]:bottomRight[1], :]
    alpha = img[:, :, -1]/255.0
    paddedFrames[idx, :, :3] = ((img[:, :, :-1]/255.0)*np.reshape(alpha, (alpha.shape[0], alpha.shape[1], 1)) + 
                                 bgPatch*(1.0-np.reshape(alpha, (alpha.shape[0], alpha.shape[1], 1))))[:, :, :3].reshape((paddedFrames.shape[1], 3)).astype(np.float32)
    
imageSize = np.array((bottomRight[0]-topLeft[0], bottomRight[1]-topLeft[1]))

## initialize features parameters

displacements = np.concatenate((np.array([[0], [0]], int),
                                np.array([np.zeros(len(dirDisplacements)), dirDisplacements], int), ## EAST
                                np.array([dirDisplacements, dirDisplacements], int), ## SOUT-EAST
                                np.array([dirDisplacements, np.zeros(len(dirDisplacements))], int), ## SOUTH
                                np.array([dirDisplacements, -dirDisplacements], int), ## SOUTH-WEST
                                np.array([np.zeros(len(dirDisplacements)), -dirDisplacements], int), ## WEST
                                np.array([-dirDisplacements, -dirDisplacements], int), ## NORTH-WEST
                                np.array([-dirDisplacements, np.zeros(len(dirDisplacements))], int), ## NORTH
                                np.array([-dirDisplacements, dirDisplacements], int), ## NORTH-EAST
                                ), axis=-1)

patchYs = np.arange(np.max(displacements), imageSize[0]-patchSize[0]-np.max(displacements), spacing)
patchYs = patchYs.reshape((1, len(patchYs)))
patchXs = np.arange(np.max(displacements), imageSize[1]-patchSize[1]-np.max(displacements), spacing)
patchXs = patchXs.reshape((1, len(patchXs)))
patchLocations = np.array(np.concatenate((patchYs.repeat(len(patchXs.T)),
                                          patchXs.repeat(len(patchYs.T), axis=0).flatten())).reshape((2, len(patchXs.T)*len(patchYs.T))), int)

frame1Idxs = np.empty((0, 2), dtype=int)
frame2Idxs = np.empty((0, 2), dtype=int)
for i, locSlice in enumerate(np.arange(patchXs.shape[-1], patchLocations.shape[-1]+1, patchXs.shape[-1])) :
    frame1Idxs = np.concatenate((frame1Idxs, np.repeat(patchLocations[:, locSlice-patchXs.shape[-1]:locSlice], len(displacements.T), axis=1).T), axis=0)
    frame2Idxs = np.concatenate((frame2Idxs, np.array([disp + loc for loc in patchLocations[:, locSlice-patchXs.shape[-1]:locSlice].T for disp in displacements.T])), axis=0)
    
stencils2D = cgf.stencil2D(gridSize[0], gridSize[1], [imageSize[0], imageSize[1], 3])
# Out:
# starting tara2
# /home/ilisescu/tara2-maskedFlow/ already exists
# Frames 0 of 1320 done
# Frames 1 of 1320 done
# Frames 2 of 1320 done
# Frames 3 of 1320 done
# Frames 4 of 1320 done
# Frames 5 of 1320 done
# Frames 6 of 1320 done
# Frames 7 of 1320 done
# Frames 8 of 1320 done
# Frames 9 of 1320 done
# Frames 10 of 1320 done
# Frames 11 of 1320 done
# Frames 12 of 1320 done
# Frames 13 of 1320 done
# Frames 14 of 1320 done
# Frames 15 of 1320 done
# Frames 16 of 1320 done
# Frames 17 of 1320 done
# Frames 18 of 1320 done
# Frames 19 of 1320 done
# Frames 20 of 1320 done
# Frames 21 of 1320 done
# Frames 22 of 1320 done
# Frames 23 of 1320 done
# Frames 24 of 1320 done
# Frames 25 of 1320 done
# Frames 26 of 1320 done
# Frames 27 of 1320 done
# Frames 28 of 1320 done
# Frames 29 of 1320 done
# Frames 30 of 1320 done
# Frames 31 of 1320 done
# Frames 32 of 1320 done
# Frames 33 of 1320 done
# Frames 34 of 1320 done
# Frames 35 of 1320 done
# Frames 36 of 1320 done
# Frames 37 of 1320 done
# Frames 38 of 1320 done
# Frames 39 of 1320 done
# Frames 40 of 1320 done
# Frames 41 of 1320 done
# Frames 42 of 1320 done
# Frames 43 of 1320 done
# Frames 44 of 1320 done
# Frames 45 of 1320 done
# Frames 46 of 1320 done
# Frames 47 of 1320 done
# Frames 48 of 1320 done
# Frames 49 of 1320 done
# Frames 50 of 1320 done
# Frames 51 of 1320 done
# Frames 52 of 1320 done
# Frames 53 of 1320 done
# Frames 54 of 1320 done
# Frames 55 of 1320 done
# Frames 56 of 1320 done
# Frames 57 of 1320 done
# Frames 58 of 1320 done
# Frames 59 of 1320 done
# Frames 60 of 1320 done
# Frames 61 of 1320 done
# Frames 62 of 1320 done
# Frames 63 of 1320 done
# Frames 64 of 1320 done
# Frames 65 of 1320 done
# Frames 66 of 1320 done
# Frames 67 of 1320 done
# Frames 68 of 1320 done
# Frames 69 of 1320 done
# Frames 70 of 1320 done
# Frames 71 of 1320 done
# Frames 72 of 1320 done
# Frames 73 of 1320 done
# Frames 74 of 1320 done
# Frames 75 of 1320 done
# Frames 76 of 1320 done
# Frames 77 of 1320 done
# Frames 78 of 1320 done
# Frames 79 of 1320 done
# Frames 80 of 1320 done
# Frames 81 of 1320 done
# Frames 82 of 1320 done
# Frames 83 of 1320 done
# Frames 84 of 1320 done
# Frames 85 of 1320 done
# Frames 86 of 1320 done
# Frames 87 of 1320 done
# Frames 88 of 1320 done
# Frames 89 of 1320 done
# Frames 90 of 1320 done
# Frames 91 of 1320 done
# Frames 92 of 1320 done
# Frames 93 of 1320 done
# Frames 94 of 1320 done
# Frames 95 of 1320 done
# Frames 96 of 1320 done
# Frames 97 of 1320 done
# Frames 98 of 1320 done
# Frames 99 of 1320 done
# Frames 100 of 1320 done
# Frames 101 of 1320 done
# Frames 102 of 1320 done
# Frames 103 of 1320 done
# Frames 104 of 1320 done
# Frames 105 of 1320 done
# Frames 106 of 1320 done
# Frames 107 of 1320 done
# Frames 108 of 1320 done
# Frames 109 of 1320 done
# Frames 110 of 1320 done
# Frames 111 of 1320 done
# Frames 112 of 1320 done
# Frames 113 of 1320 done
# Frames 114 of 1320 done
# Frames 115 of 1320 done
# Frames 116 of 1320 done
# Frames 117 of 1320 done
# Frames 118 of 1320 done
# Frames 119 of 1320 done
# Frames 120 of 1320 done
# Frames 121 of 1320 done
# Frames 122 of 1320 done
# Frames 123 of 1320 done
# Frames 124 of 1320 done
# Frames 125 of 1320 done
# Frames 126 of 1320 done
# Frames 127 of 1320 done
# Frames 128 of 1320 done
# Frames 129 of 1320 done
# Frames 130 of 1320 done
# Frames 131 of 1320 done
# Frames 132 of 1320 done
# Frames 133 of 1320 done
# Frames 134 of 1320 done
# Frames 135 of 1320 done
# Frames 136 of 1320 done
# Frames 137 of 1320 done
# Frames 138 of 1320 done
# Frames 139 of 1320 done
# Frames 140 of 1320 done
# Frames 141 of 1320 done
# Frames 142 of 1320 done
# Frames 143 of 1320 done
# Frames 144 of 1320 done
# Frames 145 of 1320 done
# Frames 146 of 1320 done
# Frames 147 of 1320 done
# Frames 148 of 1320 done
# Frames 149 of 1320 done
# Frames 150 of 1320 done
# Frames 151 of 1320 done
# Frames 152 of 1320 done
# Frames 153 of 1320 done
# Frames 154 of 1320 done
# Frames 155 of 1320 done
# Frames 156 of 1320 done
# Frames 157 of 1320 done
# Frames 158 of 1320 done
# Frames 159 of 1320 done
# Frames 160 of 1320 done
# Frames 161 of 1320 done
# Frames 162 of 1320 done
# Frames 163 of 1320 done
# Frames 164 of 1320 done
# Frames 165 of 1320 done
# Frames 166 of 1320 done
# Frames 167 of 1320 done
# Frames 168 of 1320 done
# Frames 169 of 1320 done
# Frames 170 of 1320 done
# Frames 171 of 1320 done
# Frames 172 of 1320 done
# Frames 173 of 1320 done
# Frames 174 of 1320 done
# Frames 175 of 1320 done
# Frames 176 of 1320 done
# Frames 177 of 1320 done
# Frames 178 of 1320 done
# Frames 179 of 1320 done
# Frames 180 of 1320 done
# Frames 181 of 1320 done
# Frames 182 of 1320 done
# Frames 183 of 1320 done
# Frames 184 of 1320 done
# Frames 185 of 1320 done
# Frames 186 of 1320 done
# Frames 187 of 1320 done
# Frames 188 of 1320 done
# Frames 189 of 1320 done
# Frames 190 of 1320 done
# Frames 191 of 1320 done
# Frames 192 of 1320 done
# Frames 193 of 1320 done
# Frames 194 of 1320 done
# Frames 195 of 1320 done
# Frames 196 of 1320 done
# Frames 197 of 1320 done
# Frames 198 of 1320 done
# Frames 199 of 1320 done
# Frames 200 of 1320 done
# Frames 201 of 1320 done
# Frames 202 of 1320 done
# Frames 203 of 1320 done
# Frames 204 of 1320 done
# Frames 205 of 1320 done
# Frames 206 of 1320 done
# Frames 207 of 1320 done
# Frames 208 of 1320 done
# Frames 209 of 1320 done
# Frames 210 of 1320 done
# Frames 211 of 1320 done
# Frames 212 of 1320 done
# Frames 213 of 1320 done
# Frames 214 of 1320 done
# Frames 215 of 1320 done
# Frames 216 of 1320 done
# Frames 217 of 1320 done
# Frames 218 of 1320 done
# Frames 219 of 1320 done
# Frames 220 of 1320 done
# Frames 221 of 1320 done
# Frames 222 of 1320 done
# Frames 223 of 1320 done
# Frames 224 of 1320 done
# Frames 225 of 1320 done
# Frames 226 of 1320 done
# Frames 227 of 1320 done
# Frames 228 of 1320 done
# Frames 229 of 1320 done
# Frames 230 of 1320 done
# Frames 231 of 1320 done
# Frames 232 of 1320 done
# Frames 233 of 1320 done
# Frames 234 of 1320 done
# Frames 235 of 1320 done
# Frames 236 of 1320 done
# Frames 237 of 1320 done
# Frames 238 of 1320 done
# Frames 239 of 1320 done
# Frames 240 of 1320 done
# Frames 241 of 1320 done
# Frames 242 of 1320 done
# Frames 243 of 1320 done
# Frames 244 of 1320 done
# Frames 245 of 1320 done
# Frames 246 of 1320 done
# Frames 247 of 1320 done
# Frames 248 of 1320 done
# Frames 249 of 1320 done
# Frames 250 of 1320 done
# Frames 251 of 1320 done
# Frames 252 of 1320 done
# Frames 253 of 1320 done
# Frames 254 of 1320 done
# Frames 255 of 1320 done
# Frames 256 of 1320 done
# Frames 257 of 1320 done
# Frames 258 of 1320 done
# Frames 259 of 1320 done
# Frames 260 of 1320 done
# Frames 261 of 1320 done
# Frames 262 of 1320 done
# Frames 263 of 1320 done
# Frames 264 of 1320 done
# Frames 265 of 1320 done
# Frames 266 of 1320 done
# Frames 267 of 1320 done
# Frames 268 of 1320 done
# Frames 269 of 1320 done
# Frames 270 of 1320 done
# Frames 271 of 1320 done
# Frames 272 of 1320 done
# Frames 273 of 1320 done
# Frames 274 of 1320 done
# Frames 275 of 1320 done
# Frames 276 of 1320 done
# Frames 277 of 1320 done
# Frames 278 of 1320 done
# Frames 279 of 1320 done
# Frames 280 of 1320 done
# Frames 281 of 1320 done
# Frames 282 of 1320 done
# Frames 283 of 1320 done
# Frames 284 of 1320 done
# Frames 285 of 1320 done
# Frames 286 of 1320 done
# Frames 287 of 1320 done
# Frames 288 of 1320 done
# Frames 289 of 1320 done
# Frames 290 of 1320 done
# Frames 291 of 1320 done
# Frames 292 of 1320 done
# Frames 293 of 1320 done
# Frames 294 of 1320 done
# Frames 295 of 1320 done
# Frames 296 of 1320 done
# Frames 297 of 1320 done
# Frames 298 of 1320 done
# Frames 299 of 1320 done
# Frames 300 of 1320 done
# Frames 301 of 1320 done
# Frames 302 of 1320 done
# Frames 303 of 1320 done
# Frames 304 of 1320 done
# Frames 305 of 1320 done
# Frames 306 of 1320 done
# Frames 307 of 1320 done
# Frames 308 of 1320 done
# Frames 309 of 1320 done
# Frames 310 of 1320 done
# Frames 311 of 1320 done
# Frames 312 of 1320 done
# Frames 313 of 1320 done
# Frames 314 of 1320 done
# Frames 315 of 1320 done
# Frames 316 of 1320 done
# Frames 317 of 1320 done
# Frames 318 of 1320 done
# Frames 319 of 1320 done
# Frames 320 of 1320 done
# Frames 321 of 1320 done
# Frames 322 of 1320 done
# Frames 323 of 1320 done
# Frames 324 of 1320 done
# Frames 325 of 1320 done
# Frames 326 of 1320 done
# Frames 327 of 1320 done
# Frames 328 of 1320 done
# Frames 329 of 1320 done
# Frames 330 of 1320 done
# Frames 331 of 1320 done
# Frames 332 of 1320 done
# Frames 333 of 1320 done
# Frames 334 of 1320 done
# Frames 335 of 1320 done
# Frames 336 of 1320 done
# Frames 337 of 1320 done
# Frames 338 of 1320 done
# Frames 339 of 1320 done
# Frames 340 of 1320 done
# Frames 341 of 1320 done
# Frames 342 of 1320 done
# Frames 343 of 1320 done
# Frames 344 of 1320 done
# Frames 345 of 1320 done
# Frames 346 of 1320 done
# Frames 347 of 1320 done
# Frames 348 of 1320 done
# Frames 349 of 1320 done
# Frames 350 of 1320 done
# Frames 351 of 1320 done
# Frames 352 of 1320 done
# Frames 353 of 1320 done
# Frames 354 of 1320 done
# Frames 355 of 1320 done
# Frames 356 of 1320 done
# Frames 357 of 1320 done
# Frames 358 of 1320 done
# Frames 359 of 1320 done
# Frames 360 of 1320 done
# Frames 361 of 1320 done
# Frames 362 of 1320 done
# Frames 363 of 1320 done
# Frames 364 of 1320 done
# Frames 365 of 1320 done
# Frames 366 of 1320 done
# Frames 367 of 1320 done
# Frames 368 of 1320 done
# Frames 369 of 1320 done
# Frames 370 of 1320 done
# Frames 371 of 1320 done
# Frames 372 of 1320 done
# Frames 373 of 1320 done
# Frames 374 of 1320 done
# Frames 375 of 1320 done
# Frames 376 of 1320 done
# Frames 377 of 1320 done
# Frames 378 of 1320 done
# Frames 379 of 1320 done
# Frames 380 of 1320 done
# Frames 381 of 1320 done
# Frames 382 of 1320 done
# Frames 383 of 1320 done
# Frames 384 of 1320 done
# Frames 385 of 1320 done
# Frames 386 of 1320 done
# Frames 387 of 1320 done
# Frames 388 of 1320 done
# Frames 389 of 1320 done
# Frames 390 of 1320 done
# Frames 391 of 1320 done
# Frames 392 of 1320 done
# Frames 393 of 1320 done
# Frames 394 of 1320 done
# Frames 395 of 1320 done
# Frames 396 of 1320 done
# Frames 397 of 1320 done
# Frames 398 of 1320 done
# Frames 399 of 1320 done
# Frames 400 of 1320 done
# Frames 401 of 1320 done
# Frames 402 of 1320 done
# Frames 403 of 1320 done
# Frames 404 of 1320 done
# Frames 405 of 1320 done
# Frames 406 of 1320 done
# Frames 407 of 1320 done
# Frames 408 of 1320 done
# Frames 409 of 1320 done
# Frames 410 of 1320 done
# Frames 411 of 1320 done
# Frames 412 of 1320 done
# Frames 413 of 1320 done
# Frames 414 of 1320 done
# Frames 415 of 1320 done
# Frames 416 of 1320 done
# Frames 417 of 1320 done
# Frames 418 of 1320 done
# Frames 419 of 1320 done
# Frames 420 of 1320 done
# Frames 421 of 1320 done
# Frames 422 of 1320 done
# Frames 423 of 1320 done
# Frames 424 of 1320 done
# Frames 425 of 1320 done
# Frames 426 of 1320 done
# Frames 427 of 1320 done
# Frames 428 of 1320 done
# Frames 429 of 1320 done
# Frames 430 of 1320 done
# Frames 431 of 1320 done
# Frames 432 of 1320 done
# Frames 433 of 1320 done
# Frames 434 of 1320 done
# Frames 435 of 1320 done
# Frames 436 of 1320 done
# Frames 437 of 1320 done
# Frames 438 of 1320 done
# Frames 439 of 1320 done
# Frames 440 of 1320 done
# Frames 441 of 1320 done
# Frames 442 of 1320 done
# Frames 443 of 1320 done
# Frames 444 of 1320 done
# Frames 445 of 1320 done
# Frames 446 of 1320 done
# Frames 447 of 1320 done
# Frames 448 of 1320 done
# Frames 449 of 1320 done
# Frames 450 of 1320 done
# Frames 451 of 1320 done
# Frames 452 of 1320 done
# Frames 453 of 1320 done
# Frames 454 of 1320 done
# Frames 455 of 1320 done
# Frames 456 of 1320 done
# Frames 457 of 1320 done
# Frames 458 of 1320 done
# Frames 459 of 1320 done
# Frames 460 of 1320 done
# Frames 461 of 1320 done
# Frames 462 of 1320 done
# Frames 463 of 1320 done
# Frames 464 of 1320 done
# Frames 465 of 1320 done
# Frames 466 of 1320 done
# Frames 467 of 1320 done
# Frames 468 of 1320 done
# Frames 469 of 1320 done
# Frames 470 of 1320 done
# Frames 471 of 1320 done
# Frames 472 of 1320 done
# Frames 473 of 1320 done
# Frames 474 of 1320 done
# Frames 475 of 1320 done
# Frames 476 of 1320 done
# Frames 477 of 1320 done
# Frames 478 of 1320 done
# Frames 479 of 1320 done
# Frames 480 of 1320 done
# Frames 481 of 1320 done
# Frames 482 of 1320 done
# Frames 483 of 1320 done
# Frames 484 of 1320 done
# Frames 485 of 1320 done
# Frames 486 of 1320 done
# Frames 487 of 1320 done
# Frames 488 of 1320 done
# Frames 489 of 1320 done
# Frames 490 of 1320 done
# Frames 491 of 1320 done
# Frames 492 of 1320 done
# Frames 493 of 1320 done
# Frames 494 of 1320 done
# Frames 495 of 1320 done
# Frames 496 of 1320 done
# Frames 497 of 1320 done
# Frames 498 of 1320 done
# Frames 499 of 1320 done
# Frames 500 of 1320 done
# Frames 501 of 1320 done
# Frames 502 of 1320 done
# Frames 503 of 1320 done
# Frames 504 of 1320 done
# Frames 505 of 1320 done
# Frames 506 of 1320 done
# Frames 507 of 1320 done
# Frames 508 of 1320 done
# Frames 509 of 1320 done
# Frames 510 of 1320 done
# Frames 511 of 1320 done
# Frames 512 of 1320 done
# Frames 513 of 1320 done
# Frames 514 of 1320 done
# Frames 515 of 1320 done
# Frames 516 of 1320 done
# Frames 517 of 1320 done
# Frames 518 of 1320 done
# Frames 519 of 1320 done
# Frames 520 of 1320 done
# Frames 521 of 1320 done
# Frames 522 of 1320 done
# Frames 523 of 1320 done
# Frames 524 of 1320 done
# Frames 525 of 1320 done
# Frames 526 of 1320 done
# Frames 527 of 1320 done
# Frames 528 of 1320 done
# Frames 529 of 1320 done
# Frames 530 of 1320 done
# Frames 531 of 1320 done
# Frames 532 of 1320 done
# Frames 533 of 1320 done
# Frames 534 of 1320 done
# Frames 535 of 1320 done
# Frames 536 of 1320 done
# Frames 537 of 1320 done
# Frames 538 of 1320 done
# Frames 539 of 1320 done
# Frames 540 of 1320 done
# Frames 541 of 1320 done
# Frames 542 of 1320 done
# Frames 543 of 1320 done
# Frames 544 of 1320 done
# Frames 545 of 1320 done
# Frames 546 of 1320 done
# Frames 547 of 1320 done
# Frames 548 of 1320 done
# Frames 549 of 1320 done
# Frames 550 of 1320 done
# Frames 551 of 1320 done
# Frames 552 of 1320 done
# Frames 553 of 1320 done
# Frames 554 of 1320 done
# Frames 555 of 1320 done
# Frames 556 of 1320 done
# Frames 557 of 1320 done
# Frames 558 of 1320 done
# Frames 559 of 1320 done
# Frames 560 of 1320 done
# Frames 561 of 1320 done
# Frames 562 of 1320 done
# Frames 563 of 1320 done
# Frames 564 of 1320 done
# Frames 565 of 1320 done
# Frames 566 of 1320 done
# Frames 567 of 1320 done
# Frames 568 of 1320 done
# Frames 569 of 1320 done
# Frames 570 of 1320 done
# Frames 571 of 1320 done
# Frames 572 of 1320 done
# Frames 573 of 1320 done
# Frames 574 of 1320 done
# Frames 575 of 1320 done
# Frames 576 of 1320 done
# Frames 577 of 1320 done
# Frames 578 of 1320 done
# Frames 579 of 1320 done
# Frames 580 of 1320 done
# Frames 581 of 1320 done
# Frames 582 of 1320 done
# Frames 583 of 1320 done
# Frames 584 of 1320 done
# Frames 585 of 1320 done
# Frames 586 of 1320 done
# Frames 587 of 1320 done
# Frames 588 of 1320 done
# Frames 589 of 1320 done
# Frames 590 of 1320 done
# Frames 591 of 1320 done
# Frames 592 of 1320 done
# Frames 593 of 1320 done
# Frames 594 of 1320 done
# Frames 595 of 1320 done
# Frames 596 of 1320 done
# Frames 597 of 1320 done
# Frames 598 of 1320 done
# Frames 599 of 1320 done
# Frames 600 of 1320 done
# Frames 601 of 1320 done
# Frames 602 of 1320 done
# Frames 603 of 1320 done
# Frames 604 of 1320 done
# Frames 605 of 1320 done
# Frames 606 of 1320 done
# Frames 607 of 1320 done
# Frames 608 of 1320 done
# Frames 609 of 1320 done
# Frames 610 of 1320 done
# Frames 611 of 1320 done
# Frames 612 of 1320 done
# Frames 613 of 1320 done
# Frames 614 of 1320 done
# Frames 615 of 1320 done
# Frames 616 of 1320 done
# Frames 617 of 1320 done
# Frames 618 of 1320 done
# Frames 619 of 1320 done
# Frames 620 of 1320 done
# Frames 621 of 1320 done
# Frames 622 of 1320 done
# Frames 623 of 1320 done
# Frames 624 of 1320 done
# Frames 625 of 1320 done
# Frames 626 of 1320 done
# Frames 627 of 1320 done
# Frames 628 of 1320 done
# Frames 629 of 1320 done
# Frames 630 of 1320 done
# Frames 631 of 1320 done
# Frames 632 of 1320 done
# Frames 633 of 1320 done
# Frames 634 of 1320 done
# Frames 635 of 1320 done
# Frames 636 of 1320 done
# Frames 637 of 1320 done
# Frames 638 of 1320 done
# Frames 639 of 1320 done
# Frames 640 of 1320 done
# Frames 641 of 1320 done
# Frames 642 of 1320 done
# Frames 643 of 1320 done
# Frames 644 of 1320 done
# Frames 645 of 1320 done
# Frames 646 of 1320 done
# Frames 647 of 1320 done
# Frames 648 of 1320 done
# Frames 649 of 1320 done
# Frames 650 of 1320 done
# Frames 651 of 1320 done
# Frames 652 of 1320 done
# Frames 653 of 1320 done
# Frames 654 of 1320 done
# Frames 655 of 1320 done
# Frames 656 of 1320 done
# Frames 657 of 1320 done
# Frames 658 of 1320 done
# Frames 659 of 1320 done
# Frames 660 of 1320 done
# Frames 661 of 1320 done
# Frames 662 of 1320 done
# Frames 663 of 1320 done
# Frames 664 of 1320 done
# Frames 665 of 1320 done
# Frames 666 of 1320 done
# Frames 667 of 1320 done
# Frames 668 of 1320 done
# Frames 669 of 1320 done
# Frames 670 of 1320 done
# Frames 671 of 1320 done
# Frames 672 of 1320 done
# Frames 673 of 1320 done
# Frames 674 of 1320 done
# Frames 675 of 1320 done
# Frames 676 of 1320 done
# Frames 677 of 1320 done
# Frames 678 of 1320 done
# Frames 679 of 1320 done
# Frames 680 of 1320 done
# Frames 681 of 1320 done
# Frames 682 of 1320 done
# Frames 683 of 1320 done
# Frames 684 of 1320 done
# Frames 685 of 1320 done
# Frames 686 of 1320 done
# Frames 687 of 1320 done
# Frames 688 of 1320 done
# Frames 689 of 1320 done
# Frames 690 of 1320 done
# Frames 691 of 1320 done
# Frames 692 of 1320 done
# Frames 693 of 1320 done
# Frames 694 of 1320 done
# Frames 695 of 1320 done
# Frames 696 of 1320 done
# Frames 697 of 1320 done
# Frames 698 of 1320 done
# Frames 699 of 1320 done
# Frames 700 of 1320 done
# Frames 701 of 1320 done
# Frames 702 of 1320 done
# Frames 703 of 1320 done
# Frames 704 of 1320 done
# Frames 705 of 1320 done
# Frames 706 of 1320 done
# Frames 707 of 1320 done
# Frames 708 of 1320 done
# Frames 709 of 1320 done
# Frames 710 of 1320 done
# Frames 711 of 1320 done
# Frames 712 of 1320 done
# Frames 713 of 1320 done
# Frames 714 of 1320 done
# Frames 715 of 1320 done
# Frames 716 of 1320 done
# Frames 717 of 1320 done
# Frames 718 of 1320 done
# Frames 719 of 1320 done
# Frames 720 of 1320 done
# Frames 721 of 1320 done
# Frames 722 of 1320 done
# Frames 723 of 1320 done
# Frames 724 of 1320 done
# Frames 725 of 1320 done
# Frames 726 of 1320 done
# Frames 727 of 1320 done
# Frames 728 of 1320 done
# Frames 729 of 1320 done
# Frames 730 of 1320 done
# Frames 731 of 1320 done
# Frames 732 of 1320 done
# Frames 733 of 1320 done
# Frames 734 of 1320 done
# Frames 735 of 1320 done
# Frames 736 of 1320 done
# Frames 737 of 1320 done
# Frames 738 of 1320 done
# Frames 739 of 1320 done
# Frames 740 of 1320 done
# Frames 741 of 1320 done
# Frames 742 of 1320 done
# Frames 743 of 1320 done
# Frames 744 of 1320 done
# Frames 745 of 1320 done
# Frames 746 of 1320 done
# Frames 747 of 1320 done
# Frames 748 of 1320 done
# Frames 749 of 1320 done
# Frames 750 of 1320 done
# Frames 751 of 1320 done
# Frames 752 of 1320 done
# Frames 753 of 1320 done
# Frames 754 of 1320 done
# Frames 755 of 1320 done
# Frames 756 of 1320 done
# Frames 757 of 1320 done
# Frames 758 of 1320 done
# Frames 759 of 1320 done
# Frames 760 of 1320 done
# Frames 761 of 1320 done
# Frames 762 of 1320 done
# Frames 763 of 1320 done
# Frames 764 of 1320 done
# Frames 765 of 1320 done
# Frames 766 of 1320 done
# Frames 767 of 1320 done
# Frames 768 of 1320 done
# Frames 769 of 1320 done
# Frames 770 of 1320 done
# Frames 771 of 1320 done
# Frames 772 of 1320 done
# Frames 773 of 1320 done
# Frames 774 of 1320 done
# Frames 775 of 1320 done
# Frames 776 of 1320 done
# Frames 777 of 1320 done
# Frames 778 of 1320 done
# Frames 779 of 1320 done
# Frames 780 of 1320 done
# Frames 781 of 1320 done
# Frames 782 of 1320 done
# Frames 783 of 1320 done
# Frames 784 of 1320 done
# Frames 785 of 1320 done
# Frames 786 of 1320 done
# Frames 787 of 1320 done
# Frames 788 of 1320 done
# Frames 789 of 1320 done
# Frames 790 of 1320 done
# Frames 791 of 1320 done
# Frames 792 of 1320 done
# Frames 793 of 1320 done
# Frames 794 of 1320 done
# Frames 795 of 1320 done
# Frames 796 of 1320 done
# Frames 797 of 1320 done
# Frames 798 of 1320 done
# Frames 799 of 1320 done
# Frames 800 of 1320 done
# Frames 801 of 1320 done
# Frames 802 of 1320 done
# Frames 803 of 1320 done
# Frames 804 of 1320 done
# Frames 805 of 1320 done
# Frames 806 of 1320 done
# Frames 807 of 1320 done
# Frames 808 of 1320 done
# Frames 809 of 1320 done
# Frames 810 of 1320 done
# Frames 811 of 1320 done
# Frames 812 of 1320 done
# Frames 813 of 1320 done
# Frames 814 of 1320 done
# Frames 815 of 1320 done
# Frames 816 of 1320 done
# Frames 817 of 1320 done
# Frames 818 of 1320 done
# Frames 819 of 1320 done
# Frames 820 of 1320 done
# Frames 821 of 1320 done
# Frames 822 of 1320 done
# Frames 823 of 1320 done
# Frames 824 of 1320 done
# Frames 825 of 1320 done
# Frames 826 of 1320 done
# Frames 827 of 1320 done
# Frames 828 of 1320 done
# Frames 829 of 1320 done
# Frames 830 of 1320 done
# Frames 831 of 1320 done
# Frames 832 of 1320 done
# Frames 833 of 1320 done
# Frames 834 of 1320 done
# Frames 835 of 1320 done
# Frames 836 of 1320 done
# Frames 837 of 1320 done
# Frames 838 of 1320 done
# Frames 839 of 1320 done
# Frames 840 of 1320 done
# Frames 841 of 1320 done
# Frames 842 of 1320 done
# Frames 843 of 1320 done
# Frames 844 of 1320 done
# Frames 845 of 1320 done
# Frames 846 of 1320 done
# Frames 847 of 1320 done
# Frames 848 of 1320 done
# Frames 849 of 1320 done
# Frames 850 of 1320 done
# Frames 851 of 1320 done
# Frames 852 of 1320 done
# Frames 853 of 1320 done
# Frames 854 of 1320 done
# Frames 855 of 1320 done
# Frames 856 of 1320 done
# Frames 857 of 1320 done
# Frames 858 of 1320 done
# Frames 859 of 1320 done
# Frames 860 of 1320 done
# Frames 861 of 1320 done
# Frames 862 of 1320 done
# Frames 863 of 1320 done
# Frames 864 of 1320 done
# Frames 865 of 1320 done
# Frames 866 of 1320 done
# Frames 867 of 1320 done
# Frames 868 of 1320 done
# Frames 869 of 1320 done
# Frames 870 of 1320 done
# Frames 871 of 1320 done
# Frames 872 of 1320 done
# Frames 873 of 1320 done
# Frames 874 of 1320 done
# Frames 875 of 1320 done
# Frames 876 of 1320 done
# Frames 877 of 1320 done
# Frames 878 of 1320 done
# Frames 879 of 1320 done
# Frames 880 of 1320 done
# Frames 881 of 1320 done
# Frames 882 of 1320 done
# Frames 883 of 1320 done
# Frames 884 of 1320 done
# Frames 885 of 1320 done
# Frames 886 of 1320 done
# Frames 887 of 1320 done
# Frames 888 of 1320 done
# Frames 889 of 1320 done
# Frames 890 of 1320 done
# Frames 891 of 1320 done
# Frames 892 of 1320 done
# Frames 893 of 1320 done
# Frames 894 of 1320 done
# Frames 895 of 1320 done
# Frames 896 of 1320 done
# Frames 897 of 1320 done
# Frames 898 of 1320 done
# Frames 899 of 1320 done
# Frames 900 of 1320 done
# Frames 901 of 1320 done
# Frames 902 of 1320 done
# Frames 903 of 1320 done
# Frames 904 of 1320 done
# Frames 905 of 1320 done
# Frames 906 of 1320 done
# Frames 907 of 1320 done
# Frames 908 of 1320 done
# Frames 909 of 1320 done
# Frames 910 of 1320 done
# Frames 911 of 1320 done
# Frames 912 of 1320 done
# Frames 913 of 1320 done
# Frames 914 of 1320 done
# Frames 915 of 1320 done
# Frames 916 of 1320 done
# Frames 917 of 1320 done
# Frames 918 of 1320 done
# Frames 919 of 1320 done
# Frames 920 of 1320 done
# Frames 921 of 1320 done
# Frames 922 of 1320 done
# Frames 923 of 1320 done
# Frames 924 of 1320 done
# Frames 925 of 1320 done
# Frames 926 of 1320 done
# Frames 927 of 1320 done
# Frames 928 of 1320 done
# Frames 929 of 1320 done
# Frames 930 of 1320 done
# Frames 931 of 1320 done
# Frames 932 of 1320 done
# Frames 933 of 1320 done
# Frames 934 of 1320 done
# Frames 935 of 1320 done
# Frames 936 of 1320 done
# Frames 937 of 1320 done
# Frames 938 of 1320 done
# Frames 939 of 1320 done
# Frames 940 of 1320 done
# Frames 941 of 1320 done
# Frames 942 of 1320 done
# Frames 943 of 1320 done
# Frames 944 of 1320 done
# Frames 945 of 1320 done
# Frames 946 of 1320 done
# Frames 947 of 1320 done
# Frames 948 of 1320 done
# Frames 949 of 1320 done
# Frames 950 of 1320 done
# Frames 951 of 1320 done
# Frames 952 of 1320 done
# Frames 953 of 1320 done
# Frames 954 of 1320 done
# Frames 955 of 1320 done
# Frames 956 of 1320 done
# Frames 957 of 1320 done
# Frames 958 of 1320 done
# Frames 959 of 1320 done
# Frames 960 of 1320 done
# Frames 961 of 1320 done
# Frames 962 of 1320 done
# Frames 963 of 1320 done
# Frames 964 of 1320 done
# Frames 965 of 1320 done
# Frames 966 of 1320 done
# Frames 967 of 1320 done
# Frames 968 of 1320 done
# Frames 969 of 1320 done
# Frames 970 of 1320 done
# Frames 971 of 1320 done
# Frames 972 of 1320 done
# Frames 973 of 1320 done
# Frames 974 of 1320 done
# Frames 975 of 1320 done
# Frames 976 of 1320 done
# Frames 977 of 1320 done
# Frames 978 of 1320 done
# Frames 979 of 1320 done
# Frames 980 of 1320 done
# Frames 981 of 1320 done
# Frames 982 of 1320 done
# Frames 983 of 1320 done
# Frames 984 of 1320 done
# Frames 985 of 1320 done
# Frames 986 of 1320 done
# Frames 987 of 1320 done
# Frames 988 of 1320 done
# Frames 989 of 1320 done
# Frames 990 of 1320 done
# Frames 991 of 1320 done
# Frames 992 of 1320 done
# Frames 993 of 1320 done
# Frames 994 of 1320 done
# Frames 995 of 1320 done
# Frames 996 of 1320 done
# Frames 997 of 1320 done
# Frames 998 of 1320 done
# Frames 999 of 1320 done
# Frames 1000 of 1320 done
# Frames 1001 of 1320 done
# Frames 1002 of 1320 done
# Frames 1003 of 1320 done
# Frames 1004 of 1320 done
# Frames 1005 of 1320 done
# Frames 1006 of 1320 done
# Frames 1007 of 1320 done
# Frames 1008 of 1320 done
# Frames 1009 of 1320 done
# Frames 1010 of 1320 done
# Frames 1011 of 1320 done
# Frames 1012 of 1320 done
# Frames 1013 of 1320 done
# Frames 1014 of 1320 done
# Frames 1015 of 1320 done
# Frames 1016 of 1320 done
# Frames 1017 of 1320 done
# Frames 1018 of 1320 done
# Frames 1019 of 1320 done
# Frames 1020 of 1320 done
# Frames 1021 of 1320 done
# Frames 1022 of 1320 done
# Frames 1023 of 1320 done
# Frames 1024 of 1320 done
# Frames 1025 of 1320 done
# Frames 1026 of 1320 done
# Frames 1027 of 1320 done
# Frames 1028 of 1320 done
# Frames 1029 of 1320 done
# Frames 1030 of 1320 done
# Frames 1031 of 1320 done
# Frames 1032 of 1320 done
# Frames 1033 of 1320 done
# Frames 1034 of 1320 done
# Frames 1035 of 1320 done
# Frames 1036 of 1320 done
# Frames 1037 of 1320 done
# Frames 1038 of 1320 done
# Frames 1039 of 1320 done
# Frames 1040 of 1320 done
# Frames 1041 of 1320 done
# Frames 1042 of 1320 done
# Frames 1043 of 1320 done
# Frames 1044 of 1320 done
# Frames 1045 of 1320 done
# Frames 1046 of 1320 done
# Frames 1047 of 1320 done
# Frames 1048 of 1320 done
# Frames 1049 of 1320 done
# Frames 1050 of 1320 done
# Frames 1051 of 1320 done
# Frames 1052 of 1320 done
# Frames 1053 of 1320 done
# Frames 1054 of 1320 done
# Frames 1055 of 1320 done
# Frames 1056 of 1320 done
# Frames 1057 of 1320 done
# Frames 1058 of 1320 done
# Frames 1059 of 1320 done
# Frames 1060 of 1320 done
# Frames 1061 of 1320 done
# Frames 1062 of 1320 done
# Frames 1063 of 1320 done
# Frames 1064 of 1320 done
# Frames 1065 of 1320 done
# Frames 1066 of 1320 done
# Frames 1067 of 1320 done
# Frames 1068 of 1320 done
# Frames 1069 of 1320 done
# Frames 1070 of 1320 done
# Frames 1071 of 1320 done
# Frames 1072 of 1320 done
# Frames 1073 of 1320 done
# Frames 1074 of 1320 done
# Frames 1075 of 1320 done
# Frames 1076 of 1320 done
# Frames 1077 of 1320 done
# Frames 1078 of 1320 done
# Frames 1079 of 1320 done
# Frames 1080 of 1320 done
# Frames 1081 of 1320 done
# Frames 1082 of 1320 done
# Frames 1083 of 1320 done
# Frames 1084 of 1320 done
# Frames 1085 of 1320 done
# Frames 1086 of 1320 done
# Frames 1087 of 1320 done
# Frames 1088 of 1320 done
# Frames 1089 of 1320 done
# Frames 1090 of 1320 done
# Frames 1091 of 1320 done
# Frames 1092 of 1320 done
# Frames 1093 of 1320 done
# Frames 1094 of 1320 done
# Frames 1095 of 1320 done
# Frames 1096 of 1320 done
# Frames 1097 of 1320 done
# Frames 1098 of 1320 done
# Frames 1099 of 1320 done
# Frames 1100 of 1320 done
# Frames 1101 of 1320 done
# Frames 1102 of 1320 done
# Frames 1103 of 1320 done
# Frames 1104 of 1320 done
# Frames 1105 of 1320 done
# Frames 1106 of 1320 done
# Frames 1107 of 1320 done
# Frames 1108 of 1320 done
# Frames 1109 of 1320 done
# Frames 1110 of 1320 done
# Frames 1111 of 1320 done
# Frames 1112 of 1320 done
# Frames 1113 of 1320 done
# Frames 1114 of 1320 done
# Frames 1115 of 1320 done
# Frames 1116 of 1320 done
# Frames 1117 of 1320 done
# Frames 1118 of 1320 done
# Frames 1119 of 1320 done
# Frames 1120 of 1320 done
# Frames 1121 of 1320 done
# Frames 1122 of 1320 done
# Frames 1123 of 1320 done
# Frames 1124 of 1320 done
# Frames 1125 of 1320 done
# Frames 1126 of 1320 done
# Frames 1127 of 1320 done
# Frames 1128 of 1320 done
# Frames 1129 of 1320 done
# Frames 1130 of 1320 done
# Frames 1131 of 1320 done
# Frames 1132 of 1320 done
# Frames 1133 of 1320 done
# Frames 1134 of 1320 done
# Frames 1135 of 1320 done
# Frames 1136 of 1320 done
# Frames 1137 of 1320 done
# Frames 1138 of 1320 done
# Frames 1139 of 1320 done
# Frames 1140 of 1320 done
# Frames 1141 of 1320 done
# Frames 1142 of 1320 done
# Frames 1143 of 1320 done
# Frames 1144 of 1320 done
# Frames 1145 of 1320 done
# Frames 1146 of 1320 done
# Frames 1147 of 1320 done
# Frames 1148 of 1320 done
# Frames 1149 of 1320 done
# Frames 1150 of 1320 done
# Frames 1151 of 1320 done
# Frames 1152 of 1320 done
# Frames 1153 of 1320 done
# Frames 1154 of 1320 done
# Frames 1155 of 1320 done
# Frames 1156 of 1320 done
# Frames 1157 of 1320 done
# Frames 1158 of 1320 done
# Frames 1159 of 1320 done
# Frames 1160 of 1320 done
# Frames 1161 of 1320 done
# Frames 1162 of 1320 done
# Frames 1163 of 1320 done
# Frames 1164 of 1320 done
# Frames 1165 of 1320 done
# Frames 1166 of 1320 done
# Frames 1167 of 1320 done
# Frames 1168 of 1320 done
# Frames 1169 of 1320 done
# Frames 1170 of 1320 done
# Frames 1171 of 1320 done
# Frames 1172 of 1320 done
# Frames 1173 of 1320 done
# Frames 1174 of 1320 done
# Frames 1175 of 1320 done
# Frames 1176 of 1320 done
# Frames 1177 of 1320 done
# Frames 1178 of 1320 done
# Frames 1179 of 1320 done
# Frames 1180 of 1320 done
# Frames 1181 of 1320 done
# Frames 1182 of 1320 done
# Frames 1183 of 1320 done
# Frames 1184 of 1320 done
# Frames 1185 of 1320 done
# Frames 1186 of 1320 done
# Frames 1187 of 1320 done
# Frames 1188 of 1320 done
# Frames 1189 of 1320 done
# Frames 1190 of 1320 done
# Frames 1191 of 1320 done
# Frames 1192 of 1320 done
# Frames 1193 of 1320 done
# Frames 1194 of 1320 done
# Frames 1195 of 1320 done
# Frames 1196 of 1320 done
# Frames 1197 of 1320 done
# Frames 1198 of 1320 done
# Frames 1199 of 1320 done
# Frames 1200 of 1320 done
# Frames 1201 of 1320 done
# Frames 1202 of 1320 done
# Frames 1203 of 1320 done
# Frames 1204 of 1320 done
# Frames 1205 of 1320 done
# Frames 1206 of 1320 done
# Frames 1207 of 1320 done
# Frames 1208 of 1320 done
# Frames 1209 of 1320 done
# Frames 1210 of 1320 done
# Frames 1211 of 1320 done
# Frames 1212 of 1320 done
# Frames 1213 of 1320 done
# Frames 1214 of 1320 done
# Frames 1215 of 1320 done
# Frames 1216 of 1320 done
# Frames 1217 of 1320 done
# Frames 1218 of 1320 done
# Frames 1219 of 1320 done
# Frames 1220 of 1320 done
# Frames 1221 of 1320 done
# Frames 1222 of 1320 done
# Frames 1223 of 1320 done
# Frames 1224 of 1320 done
# Frames 1225 of 1320 done
# Frames 1226 of 1320 done
# Frames 1227 of 1320 done
# Frames 1228 of 1320 done
# Frames 1229 of 1320 done
# Frames 1230 of 1320 done
# Frames 1231 of 1320 done
# Frames 1232 of 1320 done
# Frames 1233 of 1320 done
# Frames 1234 of 1320 done
# Frames 1235 of 1320 done
# Frames 1236 of 1320 done
# Frames 1237 of 1320 done
# Frames 1238 of 1320 done
# Frames 1239 of 1320 done
# Frames 1240 of 1320 done
# Frames 1241 of 1320 done
# Frames 1242 of 1320 done
# Frames 1243 of 1320 done
# Frames 1244 of 1320 done
# Frames 1245 of 1320 done
# Frames 1246 of 1320 done
# Frames 1247 of 1320 done
# Frames 1248 of 1320 done
# Frames 1249 of 1320 done
# Frames 1250 of 1320 done
# Frames 1251 of 1320 done
# Frames 1252 of 1320 done
# Frames 1253 of 1320 done
# Frames 1254 of 1320 done
# Frames 1255 of 1320 done
# Frames 1256 of 1320 done
# Frames 1257 of 1320 done
# Frames 1258 of 1320 done
# Frames 1259 of 1320 done
# Frames 1260 of 1320 done
# Frames 1261 of 1320 done
# Frames 1262 of 1320 done
# Frames 1263 of 1320 done
# Frames 1264 of 1320 done
# Frames 1265 of 1320 done
# Frames 1266 of 1320 done
# Frames 1267 of 1320 done
# Frames 1268 of 1320 done
# Frames 1269 of 1320 done
# Frames 1270 of 1320 done
# Frames 1271 of 1320 done
# Frames 1272 of 1320 done
# Frames 1273 of 1320 done
# Frames 1274 of 1320 done
# Frames 1275 of 1320 done
# Frames 1276 of 1320 done
# Frames 1277 of 1320 done
# Frames 1278 of 1320 done
# Frames 1279 of 1320 done
# Frames 1280 of 1320 done
# Frames 1281 of 1320 done
# Frames 1282 of 1320 done
# Frames 1283 of 1320 done
# Frames 1284 of 1320 done
# Frames 1285 of 1320 done
# Frames 1286 of 1320 done
# Frames 1287 of 1320 done
# Frames 1288 of 1320 done
# Frames 1289 of 1320 done
# Frames 1290 of 1320 done
# Frames 1291 of 1320 done
# Frames 1292 of 1320 done
# Frames 1293 of 1320 done
# Frames 1294 of 1320 done
# Frames 1295 of 1320 done
# Frames 1296 of 1320 done
# Frames 1297 of 1320 done
# Frames 1298 of 1320 done
# Frames 1299 of 1320 done
# Frames 1300 of 1320 done
# Frames 1301 of 1320 done
# Frames 1302 of 1320 done
# Frames 1303 of 1320 done
# Frames 1304 of 1320 done
# Frames 1305 of 1320 done
# Frames 1306 of 1320 done
# Frames 1307 of 1320 done
# Frames 1308 of 1320 done
# Frames 1309 of 1320 done
# Frames 1310 of 1320 done
# Frames 1311 of 1320 done
# Frames 1312 of 1320 done
# Frames 1313 of 1320 done
# Frames 1314 of 1320 done
# Frames 1315 of 1320 done
# Frames 1316 of 1320 done
# Frames 1317 of 1320 done
# Frames 1318 of 1320 done
# Frames 1319 of 1320 done
# computed bbox [149 861] [ 522 1104] need 2871.44352 MBs

# %%
## initializing parameters for GPU computing
displacementsForCuda = displacements.T.astype(np.int32)[:, ::-1]
offset = np.array(np.max(displacementsForCuda, axis=0)[::-1], np.int32)

cudaGridSize = np.array([np.arange(offset[0], imageSize[0]-patchSize[0]-offset[0], spacing).shape[0],
                         np.arange(offset[1], imageSize[1]-patchSize[1]-offset[1], spacing).shape[0]])

M, N = cudaGridSize.astype(np.int32)

Q = np.int32(np.prod(patchSize/[32, 32])) ## number of 32x32 quadrants
D = np.int32(len(displacementsForCuda))
quadrants = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.int32) ## hardcoded for now but whatevs

## loading kernel
module = drv.module_from_file(cudaFolder + "computeFeat/computeFeat.cubin")
computeFeatsGPU32x32 = module.get_function("computeFeats32x32")

def computeFeatsGPU(frame1, frame2) :
    ## sending data to GPU
    displacements_gpu = gpuarray.to_gpu(displacementsForCuda.flatten())

    d_img1 = gpuarray.to_gpu(frame1)
    d_img2 = gpuarray.to_gpu(frame2)
    d_feat = gpuarray.to_gpu(np.zeros((M*N*D, 1), dtype=np.float32))
    
    
    ## running kernel
    computeFeatsGPU32x32(d_feat, d_img1, d_img2, displacements_gpu, M, N, D, offset[1], offset[0], np.int32(spacing),
                         np.int32(imageSize[0]), np.int32(imageSize[1]), block=(32, 32, 1), grid=(int(N), int(M*D)))

    ## getting result
    h_feat = np.sqrt(d_feat.get()).flatten()
    return h_feat

# %%
goodPairsIdxs, badPairsIdxs = getTrainingExamples(dataPath+dataSet, numFrames, useValidatedJumps, True, verbose=False)
taggedFramesLoc = "/home/ilisescu/PhD/data/synthesisedSequences/wave-tagging_bad_jumps/tagged_frames.npy"
taggedFrames = np.load(taggedFramesLoc).item()
for key in taggedFrames :
    if taggedFrames[key][DICT_SEQUENCE_NAME] == sequence[DICT_SEQUENCE_NAME] :
        taggedFrames = taggedFrames[key][DICT_SEQUENCE_FRAMES]
        break
# print "tagged frames", taggedFrames; sys.stdout.flush()

badPairsIdxs = np.concatenate((badPairsIdxs, taggedFrames.T), axis=1)
print goodPairsIdxs
print badPairsIdxs
# Out:
# 1319 GOOD PAIRS and 1000 BAD PAIRS total
# [[   0    1    2 ..., 1316 1317 1318]
#  [   1    2    3 ..., 1317 1318 1319]]
# [[  28  875 1118 ...,  827 1228   71]
#  [ 776 1124 1222 ..., 1260  802  881]]

# %%
def getGPUFeatsForPairs(pairsIdxs) :
    featsData = np.zeros((M*N*D, len(pairsIdxs.T)))
    avgTime = 0.0
    for i, pair in enumerate(pairsIdxs.T) :
#         print pair
        t = time.time()
        ## getting features
        featsData[:, i] = computeFeatsGPU(paddedFrames[pair[0], :, :], paddedFrames[pair[1], :, :])

        avgTime = (avgTime*i + time.time()-t)/(i+1)
        remainingTime = avgTime*(len(pairsIdxs.T)-i-1)/60.0
        if np.mod(i, 200) == 0 :
            sys.stdout.write('\r' + "Done pair " + np.string_(i) + " of " + np.string_(len(pairsIdxs.T)) +
                             " (avg time: " + np.string_(avgTime) + " secs --- remaining: " +
                             np.string_(int(np.floor(remainingTime))) + ":" + np.string_(int((remainingTime - np.floor(remainingTime))*60)) + ")")
            sys.stdout.flush()
    print 
    return featsData
        
## compute feats for each pair
startTime = time.time()

goodExamplesData = getGPUFeatsForPairs(goodPairsIdxs)
badExamplesData = getGPUFeatsForPairs(badPairsIdxs)
    
print "done in", time.time()-startTime
# Out:
# Done pair 0 of 1319 (avg time: 0.00326800346375 secs --- remaining: 0:4)
# Done pair 200 of 1319 (avg time: 0.00228042626262 secs --- remaining: 0:2)
# Done pair 400 of 1319 (avg time: 0.00220090730529 secs --- remaining: 0:2)
# Done pair 600 of 1319 (avg time: 0.00222182670568 secs --- remaining: 0:1)
# Done pair 800 of 1319 (avg time: 0.00219832466783 secs --- remaining: 0:1)
# Done pair 1000 of 1319 (avg time: 0.00219503816191 secs --- remaining: 0:0)
# Done pair 1200 of 1319 (avg time: 0.00218488512984 secs --- remaining: 0:0)
# Done pair 0 of 1008 (avg time: 0.00254607200623 secs --- remaining: 0:2)
# Done pair 200 of 1008 (avg time: 0.00220376816555 secs --- remaining: 0:1)
# Done pair 400 of 1008 (avg time: 0.00219238190877 secs --- remaining: 0:1)
# Done pair 600 of 1008 (avg time: 0.0021884984859 secs --- remaining: 0:0)
# Done pair 800 of 1008 (avg time: 0.00218739848905 secs --- remaining: 0:0)
# Done pair 1000 of 1008 (avg time: 0.00218451559008 secs --- remaining: 0:0)
# done in 5.11715602875

# %%
def getTrainingData(goodPairsToUse, goodExamplesData, badPairsToUse, badExamplesData, saveLoc, labelMultiplier = 1) : 
    ### X has shape [featSize, numPairs]
        
    X = np.concatenate((goodExamplesData[:, goodPairsToUse], badExamplesData[:, badPairsToUse]), axis=1)
    w = np.concatenate((np.zeros(len(goodPairsToUse)), labelMultiplier*np.ones(len(badPairsToUse)))).reshape((X.shape[-1], 1))
    sio.savemat(saveLoc, {"X":X, "w":w})
    
    return X, w

trainingExamplesLoc = dataPath + dataSet + "trainingExamplesForImageData"
featsGoodSubset = arange(len(goodExamplesData[0]))
featsBadSubset = arange(len(badExamplesData[0]))
X, w = getTrainingData(arange(len(goodPairsIdxs.T)), goodExamplesData[:, featsGoodSubset], arange(len(badPairsIdxs.T)),
                       badExamplesData[:, featsBadSubset], trainingExamplesLoc)

phiSaveLoc = dataPath + dataSet + "fittedPhiForImageDataUsingPsi.mat"

matlabCommand = "cd ~/PhD/MATLAB/; matlab -nosplash -nodesktop -nodisplay -r "
matlabCommand += "\"fitPsiForRegression '" + trainingExamplesLoc + "' '"
matlabCommand += phiSaveLoc + "'; exit;\""

stat, output = commands.getstatusoutput(matlabCommand)
stat /= 256

if stat == 10 :
    print "Error when saving result"
elif stat == 11 :
    print "Error when loading examples"
else :
    print "Optimization completed with status", stat
    
print output
# Out:
# Optimization completed with status 0
#
#                             < M A T L A B (R) >
#                   Copyright 1984-2014 The MathWorks, Inc.
#                    R2014b (8.4.0.150421) 64-bit (glnxa64)
#                              September 15, 2014
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
# Loaded 2327 examples of size 2460
# Warning: Struct field assignment overwrites a value with class "double". See
# MATLAB R14SP2 Release Notes, Assigning Nonstructure Variables As Structures
# Displays Warning, for details.]
# > In fitPsiForRegression at 52]
# f is 2186927707097.375 g size is 2460
#  Iteration   FunEvals     Step Length    Function Val        Opt Cond
# newtonCG stopped on iteration 1 w/ residual 3.14323e+10
#          1          3     1.00000e+00     9.54169e+11     1.37585e+09
# newtonCG stopped on iteration 1 w/ residual 5.05849e+09
#          2          5     1.00000e+00     3.74675e+11     4.22165e+08
# newtonCG stopped on iteration 1 w/ residual 1.41349e+09
#          3          7     1.00000e+00     1.43137e+11     1.41117e+08
# newtonCG stopped on iteration 1 w/ residual 4.07411e+08
#          4          9     1.00000e+00     5.37803e+10     4.89724e+07
# newtonCG stopped on iteration 1 w/ residual 1.11297e+08
#          5         11     1.00000e+00     1.99937e+10     1.73611e+07
# newtonCG stopped on iteration 1 w/ residual 2.83974e+07
#          6         13     1.00000e+00     7.38872e+09     6.24113e+06
# newtonCG stopped on iteration 1 w/ residual 6.87979e+06
#          7         15     1.00000e+00     2.72238e+09     2.26465e+06
# newtonCG stopped on iteration 1 w/ residual 1.64294e+06
#          8         17     1.00000e+00     1.00155e+09     8.26542e+05
# newtonCG stopped on iteration 1 w/ residual 4.13101e+05
#          9         19     1.00000e+00     3.68091e+08     3.02717e+05
# newtonCG stopped on iteration 1 w/ residual 1.16111e+05
#         10         21     1.00000e+00     1.35138e+08     1.11068e+05
# newtonCG stopped on iteration 1 w/ residual 3.58349e+04
#         11         23     1.00000e+00     4.95486e+07     4.07898e+04
# newtonCG stopped on iteration 1 w/ residual 1.13878e+04
#         12         25     1.00000e+00     1.81414e+07     1.49784e+04
# newtonCG stopped on iteration 1 w/ residual 3.55602e+03
#         13         27     1.00000e+00     6.63986e+06     5.49930e+03
# newtonCG stopped on iteration 1 w/ residual 1.09099e+03
#         14         29     1.00000e+00     2.44264e+06     2.01708e+03
# newtonCG stopped on iteration 1 w/ residual 3.56718e+02
#         15         31     1.00000e+00     9.20529e+05     7.38203e+02
# newtonCG stopped on iteration 1 w/ residual 1.37948e+02
#         16         33     1.00000e+00     3.75042e+05     2.68891e+02
# newtonCG stopped on iteration 1 w/ residual 6.53622e+01
#         17         35     1.00000e+00     1.84146e+05     9.69260e+01
# newtonCG stopped on iteration 1 w/ residual 3.87926e+01
#         18         37     1.00000e+00     1.20657e+05     3.41056e+01
# newtonCG stopped on iteration 1 w/ residual 2.80515e+01
#         19         39     1.00000e+00     1.01849e+05     1.13357e+01
# newtonCG stopped on iteration 1 w/ residual 2.37650e+01
#         20         41     1.00000e+00     9.76073e+04     3.32030e+00
# newtonCG stopped on iteration 1 w/ residual 2.24575e+01
#         21         43     1.00000e+00     9.70821e+04     3.53259e+00
# newtonCG stopped on iteration 2 w/ residual 7.14619e+00
#         22         46     1.00000e+00     9.69961e+04     2.29903e+00
# newtonCG stopped on iteration 1 w/ residual 4.92023e+00
#         23         48     1.00000e+00     9.69799e+04     9.14685e-01
# newtonCG stopped on iteration 1 w/ residual 9.10138e-01
#         24         50     1.00000e+00     9.69770e+04     2.62871e-01
# newtonCG stopped on iteration 1 w/ residual 5.34892e-01
#         25         52     1.00000e+00     9.69770e+04     3.14221e-01
# newtonCG stopped on iteration 2 w/ residual 3.82618e-02
#         26         55     1.00000e+00     9.69770e+04     9.61975e-03
# newtonCG stopped on iteration 2 w/ residual 1.97748e-03
#         27         58     1.00000e+00     9.69769e+04     1.22142e-03
# newtonCG stopped on iteration 3 w/ residual 1.82261e-06
#         28         62     1.00000e+00     9.69769e+04     4.93728e-07
# Optimality Condition below optTol
# Exit flag of optimization is 1
# Saved phi_MAP as /media/ilisescu/Data1/PhD/data/wave2/fittedPhiForImageDataUsingPsi.mat

# %%
# # pairsToCompute = np.argwhere(np.triu(np.ones((numFrames, numFrames)), k=1))
# print pairsToCompute.shape[0], M*N*D, pairsToCompute.shape[0]*M*N*D*4.0/1000000

# pairsToCompute = np.argwhere(np.triu(np.ones((numFrames, numFrames)), k=1))
# numSubsets = 2 #1
# subsetSize = len(pairsToCompute)/numSubsets
# gridStencils = cgf.stencil2D(gridSize[0], gridSize[1], [imageSize[0], imageSize[1], 3])

# for i in arange(numSubsets)[1:] :
#     startTime = time.time()
# #     feats = np.zeros((subsetSize, len(gridStencils)))
    
#     print pairsToCompute[subsetSize*i:subsetSize*(i+1), :].T.shape
    
#     subsetFeats = getGPUFeatsForPairs(pairsToCompute[subsetSize*i:subsetSize*(i+1), :].T)
        
#     np.save("/".join(sequence[DICT_SEQUENCE_LOCATION].split("/")[:-1])+"/"+"features-"+sequence[DICT_SEQUENCE_NAME]+"-subset"+np.string_(i)+".npy", subsetFeats)
#     del subsetFeats

#     # print (f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs].reshape((subsetSize, len(stencil[0])))/255.0).shape
#     print 
#     print "done subset", i, "in", time.time() - startTime, "secs"
# Out:
# 870540 2460 8566.1136
# (2, 435270)
# Done pair 0 of 435270 (avg time: 0.00593709945679 secs --- remaining: 43:4)
# Done pair 200 of 435270 (avg time: 0.00230851813928 secs --- remaining: 16:44)
# Done pair 402400 of 435270 (avg time: 0.00227480529185 secs --- remaining: 1:14)
# Done pair 402600 of 435270 (avg time: 0.0022749103302 secs --- remaining: 1:14)
# Done pair 402800 of 435270 (avg time: 0.00227490034831 secs --- remaining: 1:13)
# Done pair 403000 of 435270 (avg time: 0.00227494705178 secs --- remaining: 1:13)
# Done pair 403200 of 435270 (avg time: 0.00227491799523 secs --- remaining: 1:12)
# Done pair 403400 of 435270 (avg time: 0.0022749085309 secs --- remaining: 1:12)
# Done pair 403600 of 435270 (avg time: 0.00227486994358 secs --- remaining: 1:12)
# Done pair 403800 of 435270 (avg time: 0.00227483683358 secs --- remaining: 1:11)
# Done pair 404000 of 435270 (avg time: 0.00227480915204 secs --- remaining: 1:11)
# Done pair 404200 of 435270 (avg time: 0.00227477189276 secs --- remaining: 1:10)
# Done pair 404400 of 435270 (avg time: 0.0022747774535 secs --- remaining: 1:10)
# Done pair 404600 of 435270 (avg time: 0.00227476726703 secs --- remaining: 1:9)
# Done pair 404800 of 435270 (avg time: 0.0022747414044 secs --- remaining: 1:9)
# Done pair 405000 of 435270 (avg time: 0.00227470646858 secs --- remaining: 1:8)
# Done pair 405200 of 435270 (avg time: 0.00227469878113 secs --- remaining: 1:8)
# Done pair 405400 of 435270 (avg time: 0.00227466367262 secs --- remaining: 1:7)
# Done pair 405600 of 435270 (avg time: 0.00227465198732 secs --- remaining: 1:7)
# Done pair 405800 of 435270 (avg time: 0.00227465210636 secs --- remaining: 1:7)
# Done pair 406000 of 435270 (avg time: 0.00227465245372 secs --- remaining: 1:6)
# Done pair 406200 of 435270 (avg time: 0.00227461609247 secs --- remaining: 1:6)
# Done pair 406400 of 435270 (avg time: 0.0022746293109 secs --- remaining: 1:5)
# Done pair 406600 of 435270 (avg time: 0.00227458579266 secs --- remaining: 1:5)
# Done pair 406800 of 435270 (avg time: 0.00227455447723 secs --- remaining: 1:4)
# Done pair 407000 of 435270 (avg time: 0.00227453707178 secs --- remaining: 1:4)
# Done pair 407200 of 435270 (avg time: 0.00227451109289 secs --- remaining: 1:3)
# Done pair 407400 of 435270 (avg time: 0.0022744884577 secs --- remaining: 1:3)
# Done pair 407600 of 435270 (avg time: 0.00227444334417 secs --- remaining: 1:2)
# Done pair 407800 of 435270 (avg time: 0.00227441485833 secs --- remaining: 1:2)
# Done pair 408000 of 435270 (avg time: 0.00227438157888 secs --- remaining: 1:2)
# Done pair 408200 of 435270 (avg time: 0.00227435095393 secs --- remaining: 1:1)
# Done pair 408400 of 435270 (avg time: 0.00227433175973 secs --- remaining: 1:1)
# Done pair 408600 of 435270 (avg time: 0.00227430033549 secs --- remaining: 1:0)
# Done pair 408800 of 435270 (avg time: 0.00227426978475 secs --- remaining: 1:0)
# Done pair 409000 of 435270 (avg time: 0.002274235845 secs --- remaining: 0:59)
# Done pair 409200 of 435270 (avg time: 0.00227424198881 secs --- remaining: 0:59)
# Done pair 409400 of 435270 (avg time: 0.00227420251272 secs --- remaining: 0:58)
# Done pair 409600 of 435270 (avg time: 0.00227416862818 secs --- remaining: 0:58)
# Done pair 431800 of 435270 (avg time: 0.00228023731415 secs --- remaining: 0:7)
# Done pair 432000 of 435270 (avg time: 0.00228040413795 secs --- remaining: 0:7)
# Done pair 432200 of 435270 (avg time: 0.00228045212075 secs --- remaining: 0:6)
# Done pair 432400 of 435270 (avg time: 0.00228050459979 secs --- remaining: 0:6)
# Done pair 432600 of 435270 (avg time: 0.00228045933072 secs --- remaining: 0:6)
# Done pair 432800 of 435270 (avg time: 0.00228039992457 secs --- remaining: 0:5)
# Done pair 433000 of 435270 (avg time: 0.00228034026384 secs --- remaining: 0:5)
# Done pair 433200 of 435270 (avg time: 0.00228033019433 secs --- remaining: 0:4)
# Done pair 433400 of 435270 (avg time: 0.00228041994678 secs --- remaining: 0:4)
# Done pair 433600 of 435270 (avg time: 0.00228047329836 secs --- remaining: 0:3)
# Done pair 433800 of 435270 (avg time: 0.00228053773462 secs --- remaining: 0:3)
# Done pair 434000 of 435270 (avg time: 0.00228062939443 secs --- remaining: 0:2)
# Done pair 434200 of 435270 (avg time: 0.00228070396975 secs --- remaining: 0:2)
# Done pair 434400 of 435270 (avg time: 0.00228076759445 secs --- remaining: 0:1)
# Done pair 434600 of 435270 (avg time: 0.00228091200275 secs --- remaining: 0:1)
# Done pair 434800 of 435270 (avg time: 0.00228121058039 secs --- remaining: 0:1)
# Done pair 435000 of 435270 (avg time: 0.00228136177133 secs --- remaining: 0:0)
# Done pair 435200 of 435270 (avg time: 0.0022814579143 secs --- remaining: 0:0)
# done subset 1 in 1086.046556 secs

# %%
distMat = np.zeros((numFrames, numFrames))
regressedWeights = sio.loadmat(phiSaveLoc)["phi_MAP"]
for i, subsetLoc in enumerate(np.sort(glob.glob("/".join(sequence[DICT_SEQUENCE_LOCATION].split("/")[:-1])+"/"+"features-*.npy"))) :
    distMat[pairsToCompute[subsetSize*i:subsetSize*(i+1), 0],
            pairsToCompute[subsetSize*i:subsetSize*(i+1), 1]] = np.dot(np.load(subsetLoc).T, regressedWeights).flatten()
    print subsetLoc
distMat[pairsToCompute[:, 1], pairsToCompute[:, 0]] = distMat[pairsToCompute[:, 0], pairsToCompute[:, 1]]
distMat[arange(numFrames), arange(numFrames)] = np.max(distMat)
gwv.showCustomGraph(distMat)
# Out:
# /media/ilisescu/Data1/PhD/data/wave2/features-tara2-subset0.npy
# /media/ilisescu/Data1/PhD/data/wave2/features-tara2-subset1.npy

# %%
np.sort(sequence[DICT_BBOXES].keys())[814]
# Out:
# 1496

# %%
print np.max(np.abs(regressedWeights-sio.loadmat(phiSaveLoc)["phi_MAP"]))
# Out:
# 0.0905116751378

# %%
filterSize = 0
GRAPH_MAX_COST = 10000000.0
if filterSize > 0 :
    optimizedDistMat = vtu.filterDistanceMatrix(distMat, filterSize, True)
else :
    optimizedDistMat = np.copy(distMat)

## if using vanilla
if False :
    optimizedDistMat = optimizedDistMat[1:optimizedDistMat.shape[1], 0:-1]
    correction = 1
else :
    ## setting diagonal to 0 as the learned distance won't have it
#     optimizedDistMat[np.argwhere(np.eye(numFrames-filterSize*2, k=1))[:, 0],
#                      np.argwhere(np.eye(numFrames-filterSize*2, k=1))[:, 1]] = 0
    correction = 0

## don't want to jump too close so increase costs in a window
minJumpLength = 20
tmp = (np.triu(np.ones(optimizedDistMat.shape), k=minJumpLength) +
       np.tril(np.ones(optimizedDistMat.shape), k=-minJumpLength) +
       np.eye(optimizedDistMat.shape[0], k=1))
tmp[tmp == 0] = 10.0
optimizedDistMat *= tmp
#########################################
## exponential
testCosts = np.copy(optimizedDistMat) #np.exp(np.copy(optimizedDistMat)/(np.average(optimizedDistMat)*0.15)) ## the lower the multiplier the more the stretch

#########################################
## do the thresholding based on how many jumps I want to keep per frame
desiredPercentage = 0.1 ## desired percentage of transitions to keep
jumpsToKeep = int(testCosts.shape[0]*desiredPercentage)
testCosts[np.arange(testCosts.shape[0]).repeat(testCosts.shape[0]-jumpsToKeep),
                       np.argsort(testCosts, axis=-1)[:, jumpsToKeep:].flatten()] = GRAPH_MAX_COST


## adding extra rows and columns so that the optimized matrix has the same dimensions as distMat
## for the indices that were cut out I put zero cost for jumps to frames that can still be used after optimization
testCosts = np.concatenate((np.ones((testCosts.shape[0], filterSize))*np.max(testCosts),
                                         testCosts,
                                         np.ones((testCosts.shape[0], filterSize+correction))*np.max(testCosts)), axis=1)
testCosts = np.concatenate((np.roll(np.concatenate((np.zeros((filterSize, 1)),
                                                                 np.ones((filterSize, distMat.shape[0]-1))*np.max(testCosts)), axis=1), filterSize, axis=1),
                                         testCosts,
                                         np.roll(np.concatenate((np.zeros((filterSize+correction, 1)),
                                                                 np.ones((filterSize+correction, distMat.shape[0]-1))*np.max(testCosts)), axis=1), filterSize, axis=1)), axis=0)




gwv.showCustomGraph(testCosts)

# %%
# gwv.showCustomGraph(testCosts-np.load(np.load(sequence[DICT_SEQUENCE_LOCATION]).item()[DICT_TRANSITION_COSTS_LOCATION]))
print np.min(testCosts-np.load(np.load(sequence[DICT_SEQUENCE_LOCATION]).item()[DICT_TRANSITION_COSTS_LOCATION]))
# Out:
# 0.0

# %%
sequence[DICT_TRANSITION_COSTS_LOCATION] = ("/".join(sequence[DICT_SEQUENCE_LOCATION].split("/")[:-1])+"/"+
                                            "transition_costs-learned_thresholded_filtered-"+sequence[DICT_SEQUENCE_NAME]+".npy")
print "using sequence", sequence[DICT_SEQUENCE_LOCATION]
print
np.save(sequence[DICT_TRANSITION_COSTS_LOCATION], testCosts)
# np.save(sequence[DICT_SEQUENCE_LOCATION], sequence)
print "sequence uses for costs", np.load(sequence[DICT_SEQUENCE_LOCATION]).item()[DICT_TRANSITION_COSTS_LOCATION]
# Out:
# using sequence /media/ilisescu/Data1/PhD/data/wave2/semantic_sequence-tara2.npy
#
# sequence uses for costs
#  /media/ilisescu/Data1/PhD/data/wave2/transition_costs-learned_thresholded_filtered-tara2.npy

# %%
pair = np.array([828, 1256]) ## pair for tara2
pair = np.array([71, 574]) ## pair for tara2
print pair
frame1 = paddedFrames[pair[0], :, :3].reshape((imageSize[0], imageSize[1], 3))
frame2 = paddedFrames[pair[1], :, :3].reshape((imageSize[0], imageSize[1], 3))

t = time.time()
features = getPairFeats(frame1*255.0, frame2*255.0, imageSize, framePaths, frame1Idxs, frame2Idxs, patchSize, stencils2D,
                        usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid)
print time.time() - t
# Out:
# [ 71 574]
# 0.0677809715271

# %%
## visualize features
tmp = np.zeros(imageSize)
tmp[frame2Idxs[:, 0], frame2Idxs[:, 1]] = features
gwv.showCustomGraph(tmp)

# %%
# paddedImages = np.zeros((len(framePaths), np.prod(imageSize), 4), dtype=np.float32)
# for i, path in enumerate(framePaths) :
#     paddedImages[i, :, :3] = np.array(Image.open(path))[:, :, :3].reshape((paddedImages.shape[1], 3)).astype(np.float32) / 255.0
    
#     sys.stdout.write('\r' + "Loaded image " + np.string_(i) + " of " + np.string_(len(framePaths)))
#     sys.stdout.flush()
        
clear_output()
print "loaded", paddedImages.shape[0], "( D =", paddedImages.shape[1], ")"

displacements = np.concatenate((np.array([np.zeros(len(dirDisplacements)), dirDisplacements], int), ## EAST
                                np.array([dirDisplacements, dirDisplacements], int), ## SOUT-EAST
                                np.array([dirDisplacements, np.zeros(len(dirDisplacements))], int), ## SOUTH
                                np.array([dirDisplacements, -dirDisplacements], int), ## SOUTH-WEST
                                np.array([np.zeros(len(dirDisplacements)), -dirDisplacements], int), ## WEST
                                np.array([-dirDisplacements, -dirDisplacements], int), ## NORTH-WEST
                                np.array([-dirDisplacements, np.zeros(len(dirDisplacements))], int), ## NORTH
                                np.array([-dirDisplacements, dirDisplacements], int), ## NORTH-EAST
                                ), axis=-1).T.astype(np.int32)

## flipping the columns so I can get x, y coords
displacements = displacements[:, ::-1]

# N = np.int32(len(img1))
# spacing = np.int32(32)
offset = np.array(np.max(displacements, axis=0)[::-1], np.int32)
# patchSize = np.array([64, 64], np.int32)
# imageSize = np.array([h, w], np.int32)

gridSize = np.array([np.arange(offset[0], imageSize[0]-patchSize[0]-offset[0], spacing).shape[0],
                     np.arange(offset[1], imageSize[1]-patchSize[1]-offset[1], spacing).shape[0]])

maxGPUmem = 3*1024**3
print maxGPUmem
# Out:
# 3221225472

# %%
module = drv.module_from_file(cudaFolder + "computeFeat/computeFeat.cubin")
computeFeat = module.get_function("computeFeat")

# %%
displacements_gpu = gpuarray.to_gpu(displacements.flatten())
patchSize_gpu = gpuarray.to_gpu(patchSize.astype(np.int32))
offset_gpu = gpuarray.to_gpu(offset)
imageSize_gpu = gpuarray.to_gpu(np.array(imageSize, np.int32))

print drv.mem_get_info()[1]-maxGPUmem, drv.mem_get_info()[0]

pair = badPairsIdxs[:, 0]
gpuImg1 = gpuarray.to_gpu(paddedImages[pair[0], :, :])
gpuImg2 = gpuarray.to_gpu(paddedImages[pair[1], :, :])
gpuRes = gpuarray.to_gpu(numpy.zeros((np.prod(gridSize), displacements.shape[0])).astype(np.float32))

computeFeat(gpuImg1, gpuImg2, displacements_gpu, patchSize_gpu, offset_gpu, np.int32(spacing), 
            imageSize_gpu, gpuRes, block=(displacements.shape[0], 1, 1), grid=(gridSize[1], gridSize[0]))

# img1_gpu = gpuarray.to_gpu(img1)
# img2_gpu = gpuarray.to_gpu(img2)
# res_gpu = gpuarray.to_gpu(numpy.zeros((np.prod(gridSize), displacements.shape[0])).astype(np.float32))


# ## run kernel
# computeFeat(img1_gpu, img2_gpu, displacements_gpu, patchSize_gpu, offset_gpu, spacing, imageSize_gpu, res_gpu, block=(displacements.shape[0], 1, 1), grid=(gridSize[1], gridSize[0]))

## read result
# res = np.empty_like(res)
# drv.memcpy_dtoh(res, res_gpu)
res = gpuRes.get()

print drv.mem_get_info()

# del displacements_gpu, patchSize_gpu, offset_gpu, imageSize_gpu
# Out:
# 1065250816 3354828800
# (3365314560, 4286476288)

# %%
# displacements_gpu = gpuarray.to_gpu(displacements.flatten())
# patchSize_gpu = gpuarray.to_gpu(patchSize.astype(np.int32))
# offset_gpu = gpuarray.to_gpu(offset)
# imageSize_gpu = gpuarray.to_gpu(np.array(imageSize, np.int32))

# print drv.mem_get_info()[1]-maxGPUmem, drv.mem_get_info()[0]

# gpuImg1 = []
# gpuImg2 = []
# gpuRes = []
# streams = []

# memPerKernel = (np.prod(imageSize)*4*4*2 + np.prod(gridSize)*displacements.shape[0]*4 + 
#                 displacements.nbytes + patchSize.astype(np.int32).nbytes + offset.nbytes + np.array(imageSize, np.int32).nbytes)
# approxMemUsage = 0

# while approxMemUsage < 2500000000 : #drv.mem_get_info()[1]-maxGPUmem < drv.mem_get_info()[0] and len(gpuRes) < len(goodPairsIdxs.T) :
# # for i in xrange(8) :
#     pair = goodPairsIdxs[:, len(gpuRes)]
#     gpuImg1.append(gpuarray.to_gpu(paddedImages[pair[0], :, :]))
#     gpuImg2.append(gpuarray.to_gpu(paddedImages[pair[1], :, :]))
#     gpuRes.append(gpuarray.to_gpu(numpy.zeros((np.prod(gridSize), displacements.shape[0])).astype(np.float32)))
    
# #     streams.append(drv.Stream())
    
# #     computeFeat(gpuImg1[-1], gpuImg2[-1], displacements_gpu, patchSize_gpu, offset_gpu, np.int32(spacing), 
# #                 imageSize_gpu, gpuRes[-1], block=(displacements.shape[0], 1, 1), grid=(gridSize[1], gridSize[0]))#, stream=streams[-1])
    
#     approxMemUsage += (memPerKernel*1.1)

#     sys.stdout.write('\r' + "Ran pair " + np.string_(len(gpuRes)) + " of " + np.string_(len(goodPairsIdxs.T)) +
#                      " (" + np.string_(approxMemUsage/1000000) + " MB used)")
# #                      " (" + np.string_(drv.mem_get_info()[0]/1000000) + ")")
# #     sys.stdout.flush()
# # img1_gpu = gpuarray.to_gpu(img1)
# # img2_gpu = gpuarray.to_gpu(img2)
# # res_gpu = gpuarray.to_gpu(numpy.zeros((np.prod(gridSize), displacements.shape[0])).astype(np.float32))


# # ## run kernel
# # computeFeat(img1_gpu, img2_gpu, displacements_gpu, patchSize_gpu, offset_gpu, spacing, imageSize_gpu, res_gpu, block=(displacements.shape[0], 1, 1), grid=(gridSize[1], gridSize[0]))

# # ## read result
# # # res = np.empty_like(res)
# # # drv.memcpy_dtoh(res, res_gpu)
# # res = res_gpu.get()

# # print drv.mem_get_info()

# # del displacements_gpu, patchSize_gpu, offset_gpu, imageSize_gpu

# %%
module = drv.module_from_file(cudaFolder + "computeFeat/computeFeat.cubin")
computeFeatsGPU64x64 = module.get_function("computeFeats64x64")

M, N = gridSize.astype(np.int32)
pair = badPairsIdxs[:, 0]

Q = np.int32(np.prod(patchSize/[32, 32])) ## number of 32x32 quadrants
D = np.int32(len(displacements))
quadrants = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.int32) ## hardcoded for now but whatevs

t = time.time()
# offset_gpu = gpuarray.to_gpu(offset)
# imageSize_gpu = gpuarray.to_gpu(np.array(imageSize, np.int32))
displacements_gpu = gpuarray.to_gpu(displacements.flatten())
quadrants_gpu = gpuarray.to_gpu(quadrants.flatten())

d_img1 = gpuarray.to_gpu(paddedImages[pair[0], :, :])
d_img2 = gpuarray.to_gpu(paddedImages[pair[1], :, :])
d_feat = gpuarray.to_gpu(np.zeros((M*N*D, 1), dtype=np.float32))
# d_poop = gpuarray.to_gpu(np.zeros((1024, 1), dtype=np.float32))

# offset_gpu = gpuarray.to_gpu(offset)
# imageSize_gpu = gpuarray.to_gpu(np.array(imageSize, np.int32))

for i in xrange(1) :
    computeFeatsGPU64x64(d_feat, d_img1, d_img2, displacements_gpu, quadrants_gpu, M, N, D, offset[1], offset[0], np.int32(spacing),
                         np.int32(imageSize[0]), np.int32(imageSize[1]), block=(32, 32, 1), grid=(int(N*Q), int(M*D)))

h_feat = d_feat.get()

print time.time() - t
# print h_feat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-7c50d7674c76> in <module>()
#      15 quadrants_gpu = gpuarray.to_gpu(quadrants.flatten())
#      16
# ---> 17 d_img1 = gpuarray.to_gpu(paddedImages[pair[0], :, :])
#      18 d_img2 = gpuarray.to_gpu(paddedImages[pair[1], :, :])
#      19 d_feat = gpuarray.to_gpu(np.zeros((M*N*D, 1), dtype=np.float32))
#
# NameError: name 'paddedImages' is not defined

# %%
print features.shape
# Out:
# (1845,)

# %%
module = drv.module_from_file(cudaFolder + "computeFeat/computeFeat.cubin")
# computeFeatsGPU32x32 = module.get_function("computeFeats32x32")
# computeFeatsGPU32x32 = module.get_function("computeFeats32x32small")
computeFeatsGPU32x32 = module.get_function("computeFeats32x32dispLoop")

M, N = gridSize.astype(np.int32)
pair = badPairsIdxs[:, 0]

Q = np.int32(np.prod(patchSize/[32, 32])) ## number of 32x32 quadrants
D = np.int32(len(displacements))
quadrants = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.int32) ## hardcoded for now but whatevs

t = time.time()
# offset_gpu = gpuarray.to_gpu(offset)
# imageSize_gpu = gpuarray.to_gpu(np.array(imageSize, np.int32))
displacements_gpu = gpuarray.to_gpu(displacements.flatten())
# quadrants_gpu = gpuarray.to_gpu(quadrants.flatten())

d_img1 = gpuarray.to_gpu(paddedImages[pair[0], :, :])
d_img2 = gpuarray.to_gpu(paddedImages[pair[1], :, :])
d_feat = gpuarray.to_gpu(np.zeros((M*N*D, 1), dtype=np.float32))
# d_poop = gpuarray.to_gpu(np.zeros((1024, 1), dtype=np.float32))

# offset_gpu = gpuarray.to_gpu(offset)
# imageSize_gpu = gpuarray.to_gpu(np.array(imageSize, np.int32))

for i in xrange(1) :
#     computeFeatsGPU32x32(d_feat, d_img1, d_img2, displacements_gpu, M, N, D, offset[1], offset[0], np.int32(spacing),
#                          np.int32(imageSize[0]), np.int32(imageSize[1]), block=(32, 32, 1), grid=(int(N), int(M*D)))
#     computeFeatsGPU32x32(d_feat, d_img1, d_img2, displacements_gpu, M, N, D, offset[1], offset[0], np.int32(spacing),
#                          np.int32(imageSize[0]), np.int32(imageSize[1]), block=(32, 4, 1), grid=(int(N*8), int(M*D)))
    computeFeatsGPU32x32(d_feat, d_img1, d_img2, displacements_gpu, M, N, D, offset[1], offset[0], np.int32(spacing),
                         np.int32(imageSize[0]), np.int32(imageSize[1]), block=(32, 4, 1), grid=(int(N*8), int(M)))

h_feat = d_feat.get()

print time.time() - t
# print h_feat
# Out:
# 0.0498299598694

# %%
tmpFolder = "/home/ilisescu/"
# seqName = "james3"
seqName = "aron1"

taggedFramesLoc = "/home/ilisescu/PhD/data/synthesisedSequences/wave/tagged_frames.npy"
taggedFrames = np.load(taggedFramesLoc).item()
for key in taggedFrames :
    if taggedFrames[key][DICT_SEQUENCE_NAME] == seqName :
        taggedFrames = taggedFrames[key][DICT_SEQUENCE_FRAMES]
        break
print "tagged frames", taggedFrames; sys.stdout.flush()
        
sequence = np.load(dataPath+dataSet+"semantic_sequence-"+seqName+".npy").item()
tmpLoc = tmpFolder+"".join(sequence[DICT_MASK_LOCATION].split("/")[-2])+"/"
print "starting", sequence[DICT_SEQUENCE_NAME]; sys.stdout.flush()

t = time.time()
if not os.path.isdir(tmpLoc) :
    copyanything(sequence[DICT_MASK_LOCATION], tmpLoc)
    print "copied folder to", tmpLoc; sys.stdout.flush()
else :
    print tmpLoc, "already exists"; sys.stdout.flush()

topLeft = np.array([720, 1280])
bottomRight = np.array([0, 0])
for i in np.sort(sequence[DICT_BBOXES].keys()) :
    alpha = np.array(Image.open(tmpLoc+"frame-{0:05d}.png".format(i+1)))[:, :, -1]
    vis = np.argwhere(alpha != 0)
    tl = np.min(vis, axis=0)
    topLeft[0] = np.min([topLeft[0], tl[0]])
    topLeft[1] = np.min([topLeft[1], tl[1]])

    br = np.max(vis, axis=0)
    bottomRight[0] = np.max([bottomRight[0], br[0]])
    bottomRight[1] = np.max([bottomRight[1], br[1]])

    sys.stdout.write('\r' + "Frames " + np.string_(i) + " of " + np.string_(len(sequence[DICT_BBOXES])) + " done")
    sys.stdout.flush()
print
print "computed bbox", topLeft, bottomRight, "need", np.prod(bottomRight-topLeft)*3*8/1000000.0*len(sequence[DICT_BBOXES]), "MBs"; sys.stdout.flush()

goodPairsIdxs, badPairsIdxs = getTrainingExamples(dataPath+dataSet, False, False, verbose=False)
badPairsIdxs = np.concatenate((badPairsIdxs, taggedFrames.T), axis=1)

patchSize = np.array([64, 64], int)
spacing = 32.0 ## how far away a patch is from the previous one

dirDisplacements = np.array([1, 2, 4, 8, 16])
gridSize = np.array((20, 20))

usePatchDisplace = False
useSSD = True
useFlow = False
useAugment = False
useSigmoid = False

imageSize = bottomRight-topLeft
framePaths = np.sort(glob.glob(tmpLoc + "frame*.png"))

goodExamplesData = getPairFeatsData(patchSize, spacing, dirDisplacements, imageSize, goodPairsIdxs, gridSize, framePaths,
                                   usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid, subPatchTopLeft=topLeft)

badExamplesData = getPairFeatsData(patchSize, spacing, dirDisplacements, imageSize, badPairsIdxs, gridSize, framePaths,
                                   usePatchDisplace, useSSD, useFlow, useAugment, useSigmoid, subPatchTopLeft=topLeft)


# numFrames = len(sprite[DICT_BBOXES])
# if np.prod(bottomRight-topLeft)*3*8/1000000.0*len(sprite[DICT_BBOXES]) > 15000 :
#     numBlocks = 4
# else :
#     numBlocks = 1
# blockSize = numFrames/numBlocks
# distMat = np.zeros([numFrames, numFrames])

# for i in xrange(0, numBlocks) :

#     f1s = np.zeros(np.hstack([bottomRight[0]-topLeft[0], bottomRight[1]-topLeft[1], 3, blockSize]), dtype=np.float64)
#     for idx, frame in enumerate(np.sort(glob.glob(tmpFolder+sprite[DICT_SEQUENCE_NAME]+"-maskedFlow/frame-0*.png"))[i*blockSize:i*blockSize+blockSize]) :
#         img = np.array(Image.open(frame), dtype=np.float64)[topLeft[0]:bottomRight[0], topLeft[1]:bottomRight[1], :]
#         alpha = img[:, :, -1]/255.0
#         f1s[:, :, :, idx] = (img[:, :, :-1]/255.0)*np.reshape(alpha, (alpha.shape[0], alpha.shape[1], 1))

#     print "loaded frames, block i=", i; sys.stdout.flush()

#     data1 = np.reshape(f1s, [np.prod(f1s.shape[0:-1]), f1s.shape[-1]]).T
#     distMat[i*blockSize:i*blockSize+blockSize, i*blockSize:i*blockSize+blockSize] = ssd(data1)
#     print "computed distance"; sys.stdout.flush()

#     for j in xrange(i+1, numBlocks) :

#         f2s = np.zeros(np.hstack([bottomRight[0]-topLeft[0], bottomRight[1]-topLeft[1], 3, blockSize]), dtype=np.float64)
#         for idx, frame in enumerate(np.sort(glob.glob(tmpFolder+sprite[DICT_SEQUENCE_NAME]+"-maskedFlow/frame-0*.png"))[j*blockSize:j*blockSize+blockSize]) :
#             img = np.array(Image.open(frame), dtype=np.float64)[topLeft[0]:bottomRight[0], topLeft[1]:bottomRight[1], :]
#             alpha = img[:, :, -1]/255.0
#             f2s[:, :, :, idx] = (img[:, :, :-1]/255.0)*np.reshape(alpha, (alpha.shape[0], alpha.shape[1], 1))

#         print "loaded frames, block j=", j; sys.stdout.flush()
#         data2 = np.reshape(f2s, [np.prod(f2s.shape[0:-1]), f2s.shape[-1]]).T
#         distMat[i*blockSize:i*blockSize+blockSize, j*blockSize:j*blockSize+blockSize] = ssd2(data1, data2)
#         distMat[j*blockSize:j*blockSize+blockSize, i*blockSize:i*blockSize+blockSize] = distMat[i*blockSize:i*blockSize+blockSize, j*blockSize:j*blockSize+blockSize].T
#         print "computed distance"; sys.stdout.flush()

#         del f2s, data2


# ## due to imprecision I need to make this check
# distMat[distMat > 0.0] = np.sqrt(distMat[distMat > 0.0])
# distMat[distMat <= 0.0] = 0.0

shutil.rmtree(tmpLoc)

# np.save(dataPath+dataSet+sprite[DICT_SEQUENCE_NAME]+"-vanilla_distMat.npy", distMat)
# del f1s, data1

# print "done", sprite[DICT_SEQUENCE_NAME], "in", time.time() - t; sys.stdout.flush()
# print 
# print
# Out:
# tagged frames [[  64  805]
#  [ 805 2940]
#  [2942 3007]
#  [3007 2762]
#  [2762 2960]]
# starting aron1
# copied folder to /home/ilisescu/aron1-maskedFlow/
# Frames 0 of 3584 done
# Frames 1 of 3584 done
# Frames 2 of 3584 done
# Frames 3 of 3584 done
# Frames 4 of 3584 done
# Frames 5 of 3584 done
# Frames 6 of 3584 done
# Frames 7 of 3584 done
# Frames 8 of 3584 done
# Frames 9 of 3584 done
# Frames 10 of 3584 done
# Frames 11 of 3584 done
# Frames 12 of 3584 done
# Frames 13 of 3584 done
# Frames 14 of 3584 done
# Frames 15 of 3584 done
# Frames 16 of 3584 done
# Frames 17 of 3584 done
# Frames 18 of 3584 done
# Frames 19 of 3584 done
# Frames 20 of 3584 done
# Frames 21 of 3584 done
# Frames 22 of 3584 done
# Frames 23 of 3584 done
# Frames 24 of 3584 done
# Frames 25 of 3584 done
# Frames 26 of 3584 done
# Frames 27 of 3584 done
# Frames 28 of 3584 done
# Frames 29 of 3584 done
# Frames 30 of 3584 done
# Frames 31 of 3584 done
# Frames 32 of 3584 done
# Frames 33 of 3584 done
# Frames 34 of 3584 done
# Frames 35 of 3584 done
# Frames 36 of 3584 done
# Frames 37 of 3584 done
# Frames 38 of 3584 done
# Frames 39 of 3584 done
# Frames 40 of 3584 done
# Frames 41 of 3584 done
# Frames 42 of 3584 done
# Frames 43 of 3584 done
# Frames 44 of 3584 done
# Frames 45 of 3584 done
# Frames 46 of 3584 done
# Frames 47 of 3584 done
# Frames 48 of 3584 done
# Frames 49 of 3584 done
# Frames 50 of 3584 done
# Frames 51 of 3584 done
# Frames 52 of 3584 done
# Frames 53 of 3584 done
# Frames 54 of 3584 done
# Frames 55 of 3584 done
# Frames 56 of 3584 done
# Frames 57 of 3584 done
# Frames 58 of 3584 done
# Frames 59 of 3584 done
# Frames 60 of 3584 done
# Frames 61 of 3584 done
# Frames 62 of 3584 done
# Frames 63 of 3584 done
# Frames 64 of 3584 done
# Frames 65 of 3584 done
# Frames 66 of 3584 done
# Frames 67 of 3584 done
# Frames 68 of 3584 done
# Frames 69 of 3584 done
# Frames 70 of 3584 done
# Frames 71 of 3584 done
# Frames 72 of 3584 done
# Frames 73 of 3584 done
# Frames 74 of 3584 done
# Frames 75 of 3584 done
# Frames 76 of 3584 done
# Frames 77 of 3584 done
# Frames 78 of 3584 done
# Frames 79 of 3584 done
# Frames 80 of 3584 done
# Frames 81 of 3584 done
# Frames 82 of 3584 done
# Frames 83 of 3584 done
# Frames 84 of 3584 done
# Frames 85 of 3584 done
# Frames 86 of 3584 done
# Frames 87 of 3584 done
# Frames 88 of 3584 done
# Frames 89 of 3584 done
# Frames 90 of 3584 done
# Frames 91 of 3584 done
# Frames 92 of 3584 done
# Frames 93 of 3584 done
# Frames 94 of 3584 done
# Frames 95 of 3584 done
# Frames 96 of 3584 done
# Frames 97 of 3584 done
# Frames 98 of 3584 done
# Frames 99 of 3584 done
# Frames 100 of 3584 done
# Frames 101 of 3584 done
# Frames 102 of 3584 done
# Frames 103 of 3584 done
# Frames 104 of 3584 done
# Frames 105 of 3584 done
# Frames 106 of 3584 done
# Frames 107 of 3584 done
# Frames 108 of 3584 done
# Frames 109 of 3584 done
# Frames 110 of 3584 done
# Frames 111 of 3584 done
# Frames 112 of 3584 done
# Frames 113 of 3584 done
# Frames 114 of 3584 done
# Frames 115 of 3584 done
# Frames 116 of 3584 done
# Frames 117 of 3584 done
# Frames 118 of 3584 done
# Frames 119 of 3584 done
# Frames 120 of 3584 done
# Frames 121 of 3584 done
# Frames 122 of 3584 done
# Frames 123 of 3584 done
# Frames 124 of 3584 done
# Frames 125 of 3584 done
# Frames 126 of 3584 done
# Frames 127 of 3584 done
# Frames 128 of 3584 done
# Frames 129 of 3584 done
# Frames 130 of 3584 done
# Frames 131 of 3584 done
# Frames 132 of 3584 done
# Frames 133 of 3584 done
# Frames 134 of 3584 done
# Frames 135 of 3584 done
# Frames 136 of 3584 done
# Frames 137 of 3584 done
# Frames 138 of 3584 done
# Frames 139 of 3584 done
# Frames 140 of 3584 done
# Frames 141 of 3584 done
# Frames 142 of 3584 done
# Frames 143 of 3584 done
# Frames 144 of 3584 done
# Frames 145 of 3584 done
# Frames 146 of 3584 done
# Frames 147 of 3584 done
# Frames 148 of 3584 done
# Frames 149 of 3584 done
# Frames 150 of 3584 done
# Frames 151 of 3584 done
# Frames 152 of 3584 done
# Frames 153 of 3584 done
# Frames 154 of 3584 done
# Frames 155 of 3584 done
# Frames 156 of 3584 done
# Frames 157 of 3584 done
# Frames 158 of 3584 done
# Frames 159 of 3584 done
# Frames 160 of 3584 done
# Frames 161 of 3584 done
# Frames 162 of 3584 done
# Frames 163 of 3584 done
# Frames 164 of 3584 done
# Frames 165 of 3584 done
# Frames 166 of 3584 done
# Frames 167 of 3584 done
# Frames 168 of 3584 done
# Frames 169 of 3584 done
# Frames 170 of 3584 done
# Frames 171 of 3584 done
# Frames 172 of 3584 done
# Frames 173 of 3584 done
# Frames 174 of 3584 done
# Frames 175 of 3584 done
# Frames 176 of 3584 done
# Frames 177 of 3584 done
# Frames 178 of 3584 done
# Frames 179 of 3584 done
# Frames 180 of 3584 done
# Frames 181 of 3584 done
# Frames 182 of 3584 done
# Frames 183 of 3584 done
# Frames 184 of 3584 done
# Frames 185 of 3584 done
# Frames 186 of 3584 done
# Frames 187 of 3584 done
# Frames 188 of 3584 done
# Frames 189 of 3584 done
# Frames 190 of 3584 done
# Frames 191 of 3584 done
# Frames 192 of 3584 done
# Frames 193 of 3584 done
# Frames 194 of 3584 done
# Frames 195 of 3584 done
# Frames 196 of 3584 done
# Frames 197 of 3584 done
# Frames 198 of 3584 done
# Frames 199 of 3584 done
# Frames 200 of 3584 done
# Frames 201 of 3584 done
# Frames 202 of 3584 done
# Frames 203 of 3584 done
# Frames 204 of 3584 done
# Frames 205 of 3584 done
# Frames 206 of 3584 done
# Frames 207 of 3584 done
# Frames 208 of 3584 done
# Frames 209 of 3584 done
# Frames 210 of 3584 done
# Frames 211 of 3584 done
# Frames 212 of 3584 done
# Frames 213 of 3584 done
# Frames 214 of 3584 done
# Frames 215 of 3584 done
# Frames 216 of 3584 done
# Frames 217 of 3584 done
# Frames 218 of 3584 done
# Frames 219 of 3584 done
# Frames 220 of 3584 done
# Frames 221 of 3584 done
# Frames 222 of 3584 done
# Frames 223 of 3584 done
# Frames 224 of 3584 done
# Frames 225 of 3584 done
# Frames 226 of 3584 done
# Frames 227 of 3584 done
# Frames 228 of 3584 done
# Frames 229 of 3584 done
# Frames 230 of 3584 done
# Frames 231 of 3584 done
# Frames 232 of 3584 done
# Frames 233 of 3584 done
# Frames 234 of 3584 done
# Frames 235 of 3584 done
# Frames 236 of 3584 done
# Frames 237 of 3584 done
# Frames 238 of 3584 done
# Frames 239 of 3584 done
# Frames 240 of 3584 done
# Frames 241 of 3584 done
# Frames 242 of 3584 done
# Frames 243 of 3584 done
# Frames 244 of 3584 done
# Frames 245 of 3584 done
# Frames 246 of 3584 done
# Frames 247 of 3584 done
# Frames 248 of 3584 done
# Frames 249 of 3584 done
# Frames 250 of 3584 done
# Frames 251 of 3584 done
# Frames 252 of 3584 done
# Frames 253 of 3584 done
# Frames 254 of 3584 done
# Frames 255 of 3584 done
# Frames 256 of 3584 done
# Frames 257 of 3584 done
# Frames 258 of 3584 done
# Frames 259 of 3584 done
# Frames 260 of 3584 done
# Frames 261 of 3584 done
# Frames 262 of 3584 done
# Frames 263 of 3584 done
# Frames 264 of 3584 done
# Frames 265 of 3584 done
# Frames 266 of 3584 done
# Frames 267 of 3584 done
# Frames 268 of 3584 done
# Frames 269 of 3584 done
# Frames 270 of 3584 done
# Frames 271 of 3584 done
# Frames 272 of 3584 done
# Frames 273 of 3584 done
# Frames 274 of 3584 done
# Frames 275 of 3584 done
# Frames 276 of 3584 done
# Frames 277 of 3584 done
# Frames 278 of 3584 done
# Frames 279 of 3584 done
# Frames 280 of 3584 done
# Frames 281 of 3584 done
# Frames 282 of 3584 done
# Frames 283 of 3584 done
# Frames 284 of 3584 done
# Frames 285 of 3584 done
# Frames 286 of 3584 done
# Frames 287 of 3584 done
# Frames 288 of 3584 done
# Frames 289 of 3584 done
# Frames 290 of 3584 done
# Frames 291 of 3584 done
# Frames 292 of 3584 done
# Frames 293 of 3584 done
# Frames 294 of 3584 done
# Frames 295 of 3584 done
# Frames 296 of 3584 done
# Frames 297 of 3584 done
# Frames 298 of 3584 done
# Frames 299 of 3584 done
# Frames 300 of 3584 done
# Frames 301 of 3584 done
# Frames 302 of 3584 done
# Frames 303 of 3584 done
# Frames 304 of 3584 done
# Frames 305 of 3584 done
# Frames 306 of 3584 done
# Frames 307 of 3584 done
# Frames 308 of 3584 done
# Frames 309 of 3584 done
# Frames 310 of 3584 done
# Frames 311 of 3584 done
# Frames 312 of 3584 done
# Frames 313 of 3584 done
# Frames 314 of 3584 done
# Frames 315 of 3584 done
# Frames 316 of 3584 done
# Frames 317 of 3584 done
# Frames 318 of 3584 done
# Frames 319 of 3584 done
# Frames 320 of 3584 done
# Frames 321 of 3584 done
# Frames 322 of 3584 done
# Frames 323 of 3584 done
# Frames 324 of 3584 done
# Frames 325 of 3584 done
# Frames 326 of 3584 done
# Frames 327 of 3584 done
# Frames 328 of 3584 done
# Frames 329 of 3584 done
# Frames 330 of 3584 done
# Frames 331 of 3584 done
# Frames 332 of 3584 done
# Frames 333 of 3584 done
# Frames 334 of 3584 done
# Frames 335 of 3584 done
# Frames 336 of 3584 done
# Frames 337 of 3584 done
# Frames 338 of 3584 done
# Frames 339 of 3584 done
# Frames 340 of 3584 done
# Frames 341 of 3584 done
# Frames 342 of 3584 done
# Frames 343 of 3584 done
# Frames 344 of 3584 done
# Frames 345 of 3584 done
# Frames 346 of 3584 done
# Frames 347 of 3584 done
# Frames 348 of 3584 done
# Frames 349 of 3584 done
# Frames 350 of 3584 done
# Frames 351 of 3584 done
# Frames 352 of 3584 done
# Frames 353 of 3584 done
# Frames 354 of 3584 done
# Frames 355 of 3584 done
# Frames 356 of 3584 done
# Frames 357 of 3584 done
# Frames 358 of 3584 done
# Frames 359 of 3584 done
# Frames 360 of 3584 done
# Frames 361 of 3584 done
# Frames 362 of 3584 done
# Frames 363 of 3584 done
# Frames 364 of 3584 done
# Frames 365 of 3584 done
# Frames 366 of 3584 done
# Frames 367 of 3584 done
# Frames 368 of 3584 done
# Frames 369 of 3584 done
# Frames 370 of 3584 done
# Frames 371 of 3584 done
# Frames 372 of 3584 done
# Frames 373 of 3584 done
# Frames 374 of 3584 done
# Frames 375 of 3584 done
# Frames 376 of 3584 done
# Frames 377 of 3584 done
# Frames 378 of 3584 done
# Frames 379 of 3584 done
# Frames 380 of 3584 done
# Frames 381 of 3584 done
# Frames 382 of 3584 done
# Frames 383 of 3584 done
# Frames 384 of 3584 done
# Frames 385 of 3584 done
# Frames 386 of 3584 done
# Frames 387 of 3584 done
# Frames 388 of 3584 done
# Frames 389 of 3584 done
# Frames 390 of 3584 done
# Frames 391 of 3584 done
# Frames 392 of 3584 done
# Frames 393 of 3584 done
# Frames 394 of 3584 done
# Frames 395 of 3584 done
# Frames 396 of 3584 done
# Frames 397 of 3584 done
# Frames 398 of 3584 done
# Frames 399 of 3584 done
# Frames 400 of 3584 done
# Frames 401 of 3584 done
# Frames 402 of 3584 done
# Frames 403 of 3584 done
# Frames 404 of 3584 done
# Frames 405 of 3584 done
# Frames 406 of 3584 done
# Frames 407 of 3584 done
# Frames 408 of 3584 done
# Frames 409 of 3584 done
# Frames 410 of 3584 done
# Frames 411 of 3584 done
# Frames 412 of 3584 done
# Frames 413 of 3584 done
# Frames 414 of 3584 done
# Frames 415 of 3584 done
# Frames 416 of 3584 done
# Frames 417 of 3584 done
# Frames 418 of 3584 done
# Frames 419 of 3584 done
# Frames 420 of 3584 done
# Frames 421 of 3584 done
# Frames 422 of 3584 done
# Frames 423 of 3584 done
# Frames 424 of 3584 done
# Frames 425 of 3584 done
# Frames 426 of 3584 done
# Frames 427 of 3584 done
# Frames 428 of 3584 done
# Frames 429 of 3584 done
# Frames 430 of 3584 done
# Frames 431 of 3584 done
# Frames 432 of 3584 done
# Frames 433 of 3584 done
# Frames 434 of 3584 done
# Frames 435 of 3584 done
# Frames 436 of 3584 done
# Frames 437 of 3584 done
# Frames 438 of 3584 done
# Frames 439 of 3584 done
# Frames 440 of 3584 done
# Frames 441 of 3584 done
# Frames 442 of 3584 done
# Frames 443 of 3584 done
# Frames 444 of 3584 done
# Frames 445 of 3584 done
# Frames 446 of 3584 done
# Frames 447 of 3584 done
# Frames 448 of 3584 done
# Frames 449 of 3584 done
# Frames 450 of 3584 done
# Frames 451 of 3584 done
# Frames 452 of 3584 done
# Frames 453 of 3584 done
# Frames 454 of 3584 done
# Frames 455 of 3584 done
# Frames 456 of 3584 done
# Frames 457 of 3584 done
# Frames 458 of 3584 done
# Frames 459 of 3584 done
# Frames 460 of 3584 done
# Frames 461 of 3584 done
# Frames 462 of 3584 done
# Frames 463 of 3584 done
# Frames 464 of 3584 done
# Frames 465 of 3584 done
# Frames 466 of 3584 done
# Frames 467 of 3584 done
# Frames 468 of 3584 done
# Frames 469 of 3584 done
# Frames 470 of 3584 done
# Frames 471 of 3584 done
# Frames 472 of 3584 done
# Frames 473 of 3584 done
# Frames 474 of 3584 done
# Frames 475 of 3584 done
# Frames 476 of 3584 done
# Frames 477 of 3584 done
# Frames 478 of 3584 done
# Frames 479 of 3584 done
# Frames 480 of 3584 done
# Frames 481 of 3584 done
# Frames 482 of 3584 done
# Frames 483 of 3584 done
# Frames 484 of 3584 done
# Frames 485 of 3584 done
# Frames 486 of 3584 done
# Frames 487 of 3584 done
# Frames 488 of 3584 done
# Frames 489 of 3584 done
# Frames 490 of 3584 done
# Frames 491 of 3584 done
# Frames 492 of 3584 done
# Frames 493 of 3584 done
# Frames 494 of 3584 done
# Frames 495 of 3584 done
# Frames 496 of 3584 done
# Frames 497 of 3584 done
# Frames 498 of 3584 done
# Frames 499 of 3584 done
# Frames 500 of 3584 done
# Frames 501 of 3584 done
# Frames 502 of 3584 done
# Frames 503 of 3584 done
# Frames 504 of 3584 done
# Frames 505 of 3584 done
# Frames 506 of 3584 done
# Frames 507 of 3584 done
# Frames 508 of 3584 done
# Frames 509 of 3584 done
# Frames 510 of 3584 done
# Frames 511 of 3584 done
# Frames 512 of 3584 done
# Frames 513 of 3584 done
# Frames 514 of 3584 done
# Frames 515 of 3584 done
# Frames 516 of 3584 done
# Frames 517 of 3584 done
# Frames 518 of 3584 done
# Frames 519 of 3584 done
# Frames 520 of 3584 done
# Frames 521 of 3584 done
# Frames 522 of 3584 done
# Frames 523 of 3584 done
# Frames 524 of 3584 done
# Frames 525 of 3584 done
# Frames 526 of 3584 done
# Frames 527 of 3584 done
# Frames 528 of 3584 done
# Frames 529 of 3584 done
# Frames 530 of 3584 done
# Frames 531 of 3584 done
# Frames 532 of 3584 done
# Frames 533 of 3584 done
# Frames 534 of 3584 done
# Frames 535 of 3584 done
# Frames 536 of 3584 done
# Frames 537 of 3584 done
# Frames 538 of 3584 done
# Frames 539 of 3584 done
# Frames 540 of 3584 done
# Frames 541 of 3584 done
# Frames 542 of 3584 done
# Frames 543 of 3584 done
# Frames 544 of 3584 done
# Frames 545 of 3584 done
# Frames 546 of 3584 done
# Frames 547 of 3584 done
# Frames 548 of 3584 done
# Frames 549 of 3584 done
# Frames 550 of 3584 done
# Frames 551 of 3584 done
# Frames 552 of 3584 done
# Frames 553 of 3584 done
# Frames 554 of 3584 done
# Frames 555 of 3584 done
# Frames 556 of 3584 done
# Frames 557 of 3584 done
# Frames 558 of 3584 done
# Frames 559 of 3584 done
# Frames 560 of 3584 done
# Frames 561 of 3584 done
# Frames 562 of 3584 done
# Frames 563 of 3584 done
# Frames 564 of 3584 done
# Frames 565 of 3584 done
# Frames 566 of 3584 done
# Frames 567 of 3584 done
# Frames 568 of 3584 done
# Frames 569 of 3584 done
# Frames 570 of 3584 done
# Frames 571 of 3584 done
# Frames 572 of 3584 done
# Frames 573 of 3584 done
# Frames 574 of 3584 done
# Frames 575 of 3584 done
# Frames 576 of 3584 done
# Frames 577 of 3584 done
# Frames 578 of 3584 done
# Frames 579 of 3584 done
# Frames 580 of 3584 done
# Frames 581 of 3584 done
# Frames 582 of 3584 done
# Frames 583 of 3584 done
# Frames 584 of 3584 done
# Frames 585 of 3584 done
# Frames 586 of 3584 done
# Frames 587 of 3584 done
# Frames 588 of 3584 done
# Frames 589 of 3584 done
# Frames 590 of 3584 done
# Frames 591 of 3584 done
# Frames 592 of 3584 done
# Frames 593 of 3584 done
# Frames 594 of 3584 done
# Frames 595 of 3584 done
# Frames 596 of 3584 done
# Frames 597 of 3584 done
# Frames 598 of 3584 done
# Frames 599 of 3584 done
# Frames 600 of 3584 done
# Frames 601 of 3584 done
# Frames 602 of 3584 done
# Frames 603 of 3584 done
# Frames 604 of 3584 done
# Frames 605 of 3584 done
# Frames 606 of 3584 done
# Frames 607 of 3584 done
# Frames 608 of 3584 done
# Frames 609 of 3584 done
# Frames 610 of 3584 done
# Frames 611 of 3584 done
# Frames 612 of 3584 done
# Frames 613 of 3584 done
# Frames 614 of 3584 done
# Frames 615 of 3584 done
# Frames 616 of 3584 done
# Frames 617 of 3584 done
# Frames 618 of 3584 done
# Frames 619 of 3584 done
# Frames 620 of 3584 done
# Frames 621 of 3584 done
# Frames 622 of 3584 done
# Frames 623 of 3584 done
# Frames 624 of 3584 done
# Frames 625 of 3584 done
# Frames 626 of 3584 done
# Frames 627 of 3584 done
# Frames 628 of 3584 done
# Frames 629 of 3584 done
# Frames 630 of 3584 done
# Frames 631 of 3584 done
# Frames 632 of 3584 done
# Frames 633 of 3584 done
# Frames 634 of 3584 done
# Frames 635 of 3584 done
# Frames 636 of 3584 done
# Frames 637 of 3584 done
# Frames 638 of 3584 done
# Frames 639 of 3584 done
# Frames 640 of 3584 done
# Frames 641 of 3584 done
# Frames 642 of 3584 done
# Frames 643 of 3584 done
# Frames 644 of 3584 done
# Frames 645 of 3584 done
# Frames 646 of 3584 done
# Frames 647 of 3584 done
# Frames 648 of 3584 done
# Frames 649 of 3584 done
# Frames 650 of 3584 done
# Frames 651 of 3584 done
# Frames 652 of 3584 done
# Frames 653 of 3584 done
# Frames 654 of 3584 done
# Frames 655 of 3584 done
# Frames 656 of 3584 done
# Frames 657 of 3584 done
# Frames 658 of 3584 done
# Frames 659 of 3584 done
# Frames 660 of 3584 done
# Frames 661 of 3584 done
# Frames 662 of 3584 done
# Frames 663 of 3584 done
# Frames 664 of 3584 done
# Frames 665 of 3584 done
# Frames 666 of 3584 done
# Frames 667 of 3584 done
# Frames 668 of 3584 done
# Frames 669 of 3584 done
# Frames 670 of 3584 done
# Frames 671 of 3584 done
# Frames 672 of 3584 done
# Frames 673 of 3584 done
# Frames 674 of 3584 done
# Frames 675 of 3584 done
# Frames 676 of 3584 done
# Frames 677 of 3584 done
# Frames 678 of 3584 done
# Frames 679 of 3584 done
# Frames 680 of 3584 done
# Frames 681 of 3584 done
# Frames 682 of 3584 done
# Frames 683 of 3584 done
# Frames 684 of 3584 done
# Frames 685 of 3584 done
# Frames 686 of 3584 done
# Frames 687 of 3584 done
# Frames 688 of 3584 done
# Frames 689 of 3584 done
# Frames 690 of 3584 done
# Frames 691 of 3584 done
# Frames 692 of 3584 done
# Frames 693 of 3584 done
# Frames 694 of 3584 done
# Frames 695 of 3584 done
# Frames 696 of 3584 done
# Frames 697 of 3584 done
# Frames 698 of 3584 done
# Frames 699 of 3584 done
# Frames 700 of 3584 done
# Frames 701 of 3584 done
# Frames 702 of 3584 done
# Frames 703 of 3584 done
# Frames 704 of 3584 done
# Frames 705 of 3584 done
# Frames 706 of 3584 done
# Frames 707 of 3584 done
# Frames 708 of 3584 done
# Frames 709 of 3584 done
# Frames 710 of 3584 done
# Frames 711 of 3584 done
# Frames 712 of 3584 done
# Frames 713 of 3584 done
# Frames 714 of 3584 done
# Frames 715 of 3584 done
# Frames 716 of 3584 done
# Frames 717 of 3584 done
# Frames 718 of 3584 done
# Frames 719 of 3584 done
# Frames 720 of 3584 done
# Frames 721 of 3584 done
# Frames 722 of 3584 done
# Frames 723 of 3584 done
# Frames 724 of 3584 done
# Frames 725 of 3584 done
# Frames 726 of 3584 done
# Frames 727 of 3584 done
# Frames 728 of 3584 done
# Frames 729 of 3584 done
# Frames 730 of 3584 done
# Frames 731 of 3584 done
# Frames 732 of 3584 done
# Frames 733 of 3584 done
# Frames 734 of 3584 done
# Frames 735 of 3584 done
# Frames 736 of 3584 done
# Frames 737 of 3584 done
# Frames 738 of 3584 done
# Frames 739 of 3584 done
# Frames 740 of 3584 done
# Frames 741 of 3584 done
# Frames 742 of 3584 done
# Frames 743 of 3584 done
# Frames 744 of 3584 done
# Frames 745 of 3584 done
# Frames 746 of 3584 done
# Frames 747 of 3584 done
# Frames 748 of 3584 done
# Frames 749 of 3584 done
# Frames 750 of 3584 done
# Frames 751 of 3584 done
# Frames 752 of 3584 done
# Frames 753 of 3584 done
# Frames 754 of 3584 done
# Frames 755 of 3584 done
# Frames 756 of 3584 done
# Frames 757 of 3584 done
# Frames 758 of 3584 done
# Frames 759 of 3584 done
# Frames 760 of 3584 done
# Frames 761 of 3584 done
# Frames 762 of 3584 done
# Frames 763 of 3584 done
# Frames 764 of 3584 done
# Frames 765 of 3584 done
# Frames 766 of 3584 done
# Frames 767 of 3584 done
# Frames 768 of 3584 done
# Frames 769 of 3584 done
# Frames 770 of 3584 done
# Frames 771 of 3584 done
# Frames 772 of 3584 done
# Frames 773 of 3584 done
# Frames 774 of 3584 done
# Frames 775 of 3584 done
# Frames 776 of 3584 done
# Frames 777 of 3584 done
# Frames 778 of 3584 done
# Frames 779 of 3584 done
# Frames 780 of 3584 done
# Frames 781 of 3584 done
# Frames 782 of 3584 done
# Frames 783 of 3584 done
# Frames 784 of 3584 done
# Frames 785 of 3584 done
# Frames 786 of 3584 done
# Frames 787 of 3584 done
# Frames 788 of 3584 done
# Frames 789 of 3584 done
# Frames 790 of 3584 done
# Frames 791 of 3584 done
# Frames 792 of 3584 done
# Frames 793 of 3584 done
# Frames 794 of 3584 done
# Frames 795 of 3584 done
# Frames 796 of 3584 done
# Frames 797 of 3584 done
# Frames 798 of 3584 done
# Frames 799 of 3584 done
# Frames 800 of 3584 done
# Frames 801 of 3584 done
# Frames 802 of 3584 done
# Frames 803 of 3584 done
# Frames 804 of 3584 done
# Frames 805 of 3584 done
# Frames 806 of 3584 done
# Frames 807 of 3584 done
# Frames 808 of 3584 done
# Frames 809 of 3584 done
# Frames 810 of 3584 done
# Frames 811 of 3584 done
# Frames 812 of 3584 done
# Frames 813 of 3584 done
# Frames 814 of 3584 done
# Frames 815 of 3584 done
# Frames 816 of 3584 done
# Frames 817 of 3584 done
# Frames 818 of 3584 done
# Frames 819 of 3584 done
# Frames 820 of 3584 done
# Frames 821 of 3584 done
# Frames 822 of 3584 done
# Frames 823 of 3584 done
# Frames 824 of 3584 done
# Frames 825 of 3584 done
# Frames 826 of 3584 done
# Frames 827 of 3584 done
# Frames 828 of 3584 done
# Frames 829 of 3584 done
# Frames 830 of 3584 done
# Frames 831 of 3584 done
# Frames 832 of 3584 done
# Frames 833 of 3584 done
# Frames 834 of 3584 done
# Frames 835 of 3584 done
# Frames 836 of 3584 done
# Frames 837 of 3584 done
# Frames 838 of 3584 done
# Frames 839 of 3584 done
# Frames 840 of 3584 done
# Frames 841 of 3584 done
# Frames 842 of 3584 done
# Frames 843 of 3584 done
# Frames 844 of 3584 done
# Frames 845 of 3584 done
# Frames 846 of 3584 done
# Frames 847 of 3584 done
# Frames 848 of 3584 done
# Frames 849 of 3584 done
# Frames 850 of 3584 done
# Frames 851 of 3584 done
# Frames 852 of 3584 done
# Frames 853 of 3584 done
# Frames 854 of 3584 done
# Frames 855 of 3584 done
# Frames 856 of 3584 done
# Frames 857 of 3584 done
# Frames 858 of 3584 done
# Frames 859 of 3584 done
# Frames 860 of 3584 done
# Frames 861 of 3584 done
# Frames 862 of 3584 done
# Frames 863 of 3584 done
# Frames 864 of 3584 done
# Frames 865 of 3584 done
# Frames 866 of 3584 done
# Frames 867 of 3584 done
# Frames 868 of 3584 done
# Frames 869 of 3584 done
# Frames 870 of 3584 done
# Frames 871 of 3584 done
# Frames 872 of 3584 done
# Frames 873 of 3584 done
# Frames 874 of 3584 done
# Frames 875 of 3584 done
# Frames 876 of 3584 done
# Frames 877 of 3584 done
# Frames 878 of 3584 done
# Frames 879 of 3584 done
# Frames 880 of 3584 done
# Frames 881 of 3584 done
# Frames 882 of 3584 done
# Frames 883 of 3584 done
# Frames 884 of 3584 done
# Frames 885 of 3584 done
# Frames 886 of 3584 done
# Frames 887 of 3584 done
# Frames 888 of 3584 done
# Frames 889 of 3584 done
# Frames 890 of 3584 done
# Frames 891 of 3584 done
# Frames 892 of 3584 done
# Frames 893 of 3584 done
# Frames 894 of 3584 done
# Frames 895 of 3584 done
# Frames 896 of 3584 done
# Frames 897 of 3584 done
# Frames 898 of 3584 done
# Frames 899 of 3584 done
# Frames 900 of 3584 done
# Frames 901 of 3584 done
# Frames 902 of 3584 done
# Frames 903 of 3584 done
# Frames 904 of 3584 done
# Frames 905 of 3584 done
# Frames 906 of 3584 done
# Frames 907 of 3584 done
# Frames 908 of 3584 done
# Frames 909 of 3584 done
# Frames 910 of 3584 done
# Frames 911 of 3584 done
# Frames 912 of 3584 done
# Frames 913 of 3584 done
# Frames 914 of 3584 done
# Frames 915 of 3584 done
# Frames 916 of 3584 done
# Frames 917 of 3584 done
# Frames 918 of 3584 done
# Frames 919 of 3584 done
# Frames 920 of 3584 done
# Frames 921 of 3584 done
# Frames 922 of 3584 done
# Frames 923 of 3584 done
# Frames 924 of 3584 done
# Frames 925 of 3584 done
# Frames 926 of 3584 done
# Frames 927 of 3584 done
# Frames 928 of 3584 done
# Frames 929 of 3584 done
# Frames 930 of 3584 done
# Frames 931 of 3584 done
# Frames 932 of 3584 done
# Frames 933 of 3584 done
# Frames 934 of 3584 done
# Frames 935 of 3584 done
# Frames 936 of 3584 done
# Frames 937 of 3584 done
# Frames 938 of 3584 done
# Frames 939 of 3584 done
# Frames 940 of 3584 done
# Frames 941 of 3584 done
# Frames 942 of 3584 done
# Frames 943 of 3584 done
# Frames 944 of 3584 done
# Frames 945 of 3584 done
# Frames 946 of 3584 done
# Frames 947 of 3584 done
# Frames 948 of 3584 done
# Frames 949 of 3584 done
# Frames 950 of 3584 done
# Frames 951 of 3584 done
# Frames 952 of 3584 done
# Frames 953 of 3584 done
# Frames 954 of 3584 done
# Frames 955 of 3584 done
# Frames 956 of 3584 done
# Frames 957 of 3584 done
# Frames 958 of 3584 done
# Frames 959 of 3584 done
# Frames 960 of 3584 done
# Frames 961 of 3584 done
# Frames 962 of 3584 done
# Frames 963 of 3584 done
# Frames 964 of 3584 done
# Frames 965 of 3584 done
# Frames 966 of 3584 done
# Frames 967 of 3584 done
# Frames 968 of 3584 done
# Frames 969 of 3584 done
# Frames 970 of 3584 done
# Frames 971 of 3584 done
# Frames 972 of 3584 done
# Frames 973 of 3584 done
# Frames 974 of 3584 done
# Frames 975 of 3584 done
# Frames 976 of 3584 done
# Frames 977 of 3584 done
# Frames 978 of 3584 done
# Frames 979 of 3584 done
# Frames 980 of 3584 done
# Frames 981 of 3584 done
# Frames 982 of 3584 done
# Frames 983 of 3584 done
# Frames 984 of 3584 done
# Frames 985 of 3584 done
# Frames 986 of 3584 done
# Frames 987 of 3584 done
# Frames 988 of 3584 done
# Frames 989 of 3584 done
# Frames 990 of 3584 done
# Frames 991 of 3584 done
# Frames 992 of 3584 done
# Frames 993 of 3584 done
# Frames 994 of 3584 done
# Frames 995 of 3584 done
# Frames 996 of 3584 done
# Frames 997 of 3584 done
# Frames 998 of 3584 done
# Frames 999 of 3584 done
# Frames 1000 of 3584 done
# Frames 1001 of 3584 done
# Frames 1002 of 3584 done
# Frames 1003 of 3584 done
# Frames 1004 of 3584 done
# Frames 1005 of 3584 done
# Frames 1006 of 3584 done
# Frames 1007 of 3584 done
# Frames 1008 of 3584 done
# Frames 1009 of 3584 done
# Frames 1010 of 3584 done
# Frames 1011 of 3584 done
# Frames 1012 of 3584 done
# Frames 1013 of 3584 done
# Frames 1014 of 3584 done
# Frames 1015 of 3584 done
# Frames 1016 of 3584 done
# Frames 1017 of 3584 done
# Frames 1018 of 3584 done
# Frames 1019 of 3584 done
# Frames 1020 of 3584 done
# Frames 1021 of 3584 done
# Frames 1022 of 3584 done
# Frames 1023 of 3584 done
# Frames 1024 of 3584 done
# Frames 1025 of 3584 done
# Frames 1026 of 3584 done
# Frames 1027 of 3584 done
# Frames 1028 of 3584 done
# Frames 1029 of 3584 done
# Frames 1030 of 3584 done
# Frames 1031 of 3584 done
# Frames 1032 of 3584 done
# Frames 1033 of 3584 done
# Frames 1034 of 3584 done
# Frames 1035 of 3584 done
# Frames 1036 of 3584 done
# Frames 1037 of 3584 done
# Frames 1038 of 3584 done
# Frames 1039 of 3584 done
# Frames 1040 of 3584 done
# Frames 1041 of 3584 done
# Frames 1042 of 3584 done
# Frames 1043 of 3584 done
# Frames 1044 of 3584 done
# Frames 1045 of 3584 done
# Frames 1046 of 3584 done
# Frames 1047 of 3584 done
# Frames 1048 of 3584 done
# Frames 1049 of 3584 done
# Frames 1050 of 3584 done
# Frames 1051 of 3584 done
# Frames 1052 of 3584 done
# Frames 1053 of 3584 done
# Frames 1054 of 3584 done
# Frames 1055 of 3584 done
# Frames 1056 of 3584 done
# Frames 1057 of 3584 done
# Frames 1058 of 3584 done
# Frames 1059 of 3584 done
# Frames 1060 of 3584 done
# Frames 1061 of 3584 done
# Frames 1062 of 3584 done
# Frames 1063 of 3584 done
# Frames 1064 of 3584 done
# Frames 1065 of 3584 done
# Frames 1066 of 3584 done
# Frames 1067 of 3584 done
# Frames 1068 of 3584 done
# Frames 1069 of 3584 done
# Frames 1070 of 3584 done
# Frames 1071 of 3584 done
# Frames 1072 of 3584 done
# Frames 1073 of 3584 done
# Frames 1074 of 3584 done
# Frames 1075 of 3584 done
# Frames 1076 of 3584 done
# Frames 1077 of 3584 done
# Frames 1078 of 3584 done
# Frames 1079 of 3584 done
# Frames 1080 of 3584 done
# Frames 1081 of 3584 done
# Frames 1082 of 3584 done
# Frames 1083 of 3584 done
# Frames 1084 of 3584 done
# Frames 1085 of 3584 done
# Frames 1086 of 3584 done
# Frames 1087 of 3584 done
# Frames 1088 of 3584 done
# Frames 1089 of 3584 done
# Frames 1090 of 3584 done
# Frames 1091 of 3584 done
# Frames 1092 of 3584 done
# Frames 1093 of 3584 done
# Frames 1094 of 3584 done
# Frames 1095 of 3584 done
# Frames 1096 of 3584 done
# Frames 1097 of 3584 done
# Frames 1098 of 3584 done
# Frames 1099 of 3584 done
# Frames 1100 of 3584 done
# Frames 1101 of 3584 done
# Frames 1102 of 3584 done
# Frames 1103 of 3584 done
# Frames 1104 of 3584 done
# Frames 1105 of 3584 done
# Frames 1106 of 3584 done
# Frames 1107 of 3584 done
# Frames 1108 of 3584 done
# Frames 1109 of 3584 done
# Frames 1110 of 3584 done
# Frames 1111 of 3584 done
# Frames 1112 of 3584 done
# Frames 1113 of 3584 done
# Frames 1114 of 3584 done
# Frames 1115 of 3584 done
# Frames 1116 of 3584 done
# Frames 1117 of 3584 done
# Frames 1118 of 3584 done
# Frames 1119 of 3584 done
# Frames 1120 of 3584 done
# Frames 1121 of 3584 done
# Frames 1122 of 3584 done
# Frames 1123 of 3584 done
# Frames 1124 of 3584 done
# Frames 1125 of 3584 done
# Frames 1126 of 3584 done
# Frames 1127 of 3584 done
# Frames 1128 of 3584 done
# Frames 1129 of 3584 done
# Frames 1130 of 3584 done
# Frames 1131 of 3584 done
# Frames 1132 of 3584 done
# Frames 1133 of 3584 done
# Frames 1134 of 3584 done
# Frames 1135 of 3584 done
# Frames 1136 of 3584 done
# Frames 1137 of 3584 done
# Frames 1138 of 3584 done
# Frames 1139 of 3584 done
# Frames 1140 of 3584 done
# Frames 1141 of 3584 done
# Frames 1142 of 3584 done
# Frames 1143 of 3584 done
# Frames 1144 of 3584 done
# Frames 1145 of 3584 done
# Frames 1146 of 3584 done
# Frames 1147 of 3584 done
# Frames 1148 of 3584 done
# Frames 1149 of 3584 done
# Frames 1150 of 3584 done
# Frames 1151 of 3584 done
# Frames 1152 of 3584 done
# Frames 1153 of 3584 done
# Frames 1154 of 3584 done
# Frames 1155 of 3584 done
# Frames 1156 of 3584 done
# Frames 1157 of 3584 done
# Frames 1158 of 3584 done
# Frames 1159 of 3584 done
# Frames 1160 of 3584 done
# Frames 1161 of 3584 done
# Frames 1162 of 3584 done
# Frames 1163 of 3584 done
# Frames 1164 of 3584 done
# Frames 1165 of 3584 done
# Frames 1166 of 3584 done
# Frames 1167 of 3584 done
# Frames 1168 of 3584 done
# Frames 1169 of 3584 done
# Frames 1170 of 3584 done
# Frames 1171 of 3584 done
# Frames 1172 of 3584 done
# Frames 1173 of 3584 done
# Frames 1174 of 3584 done
# Frames 1175 of 3584 done
# Frames 1176 of 3584 done
# Frames 1177 of 3584 done
# Frames 1178 of 3584 done
# Frames 1179 of 3584 done
# Frames 1180 of 3584 done
# Frames 1181 of 3584 done
# Frames 1182 of 3584 done
# Frames 1183 of 3584 done
# Frames 1184 of 3584 done
# Frames 1185 of 3584 done
# Frames 1186 of 3584 done
# Frames 1187 of 3584 done
# Frames 1188 of 3584 done
# Frames 1189 of 3584 done
# Frames 1190 of 3584 done
# Frames 1191 of 3584 done
# Frames 1192 of 3584 done
# Frames 1193 of 3584 done
# Frames 1194 of 3584 done
# Frames 1195 of 3584 done
# Frames 1196 of 3584 done
# Frames 1197 of 3584 done
# Frames 1198 of 3584 done
# Frames 1199 of 3584 done
# Frames 1200 of 3584 done
# Frames 1201 of 3584 done
# Frames 1202 of 3584 done
# Frames 1203 of 3584 done
# Frames 1204 of 3584 done
# Frames 1205 of 3584 done
# Frames 1206 of 3584 done
# Frames 1207 of 3584 done
# Frames 1208 of 3584 done
# Frames 1209 of 3584 done
# Frames 1210 of 3584 done
# Frames 1211 of 3584 done
# Frames 1212 of 3584 done
# Frames 1213 of 3584 done
# Frames 1214 of 3584 done
# Frames 1215 of 3584 done
# Frames 1216 of 3584 done
# Frames 1217 of 3584 done
# Frames 1218 of 3584 done
# Frames 1219 of 3584 done
# Frames 1220 of 3584 done
# Frames 1221 of 3584 done
# Frames 1222 of 3584 done
# Frames 1223 of 3584 done
# Frames 1224 of 3584 done
# Frames 1225 of 3584 done
# Frames 1226 of 3584 done
# Frames 1227 of 3584 done
# Frames 1228 of 3584 done
# Frames 1229 of 3584 done
# Frames 1230 of 3584 done
# Frames 1231 of 3584 done
# Frames 1232 of 3584 done
# Frames 1233 of 3584 done
# Frames 1234 of 3584 done
# Frames 1235 of 3584 done
# Frames 1236 of 3584 done
# Frames 1237 of 3584 done
# Frames 1238 of 3584 done
# Frames 1239 of 3584 done
# Frames 1240 of 3584 done
# Frames 1241 of 3584 done
# Frames 1242 of 3584 done
# Frames 1243 of 3584 done
# Frames 1244 of 3584 done
# Frames 1245 of 3584 done
# Frames 1246 of 3584 done
# Frames 1247 of 3584 done
# Frames 1248 of 3584 done
# Frames 1249 of 3584 done
# Frames 1250 of 3584 done
# Frames 1251 of 3584 done
# Frames 1252 of 3584 done
# Frames 1253 of 3584 done
# Frames 1254 of 3584 done
# Frames 1255 of 3584 done
# Frames 1256 of 3584 done
# Frames 1257 of 3584 done
# Frames 1258 of 3584 done
# Frames 1259 of 3584 done
# Frames 1260 of 3584 done
# Frames 1261 of 3584 done
# Frames 1262 of 3584 done
# Frames 1263 of 3584 done
# Frames 1264 of 3584 done
# Frames 1265 of 3584 done
# Frames 1266 of 3584 done
# Frames 1267 of 3584 done
# Frames 1268 of 3584 done
# Frames 1269 of 3584 done
# Frames 1270 of 3584 done
# Frames 1271 of 3584 done
# Frames 1272 of 3584 done
# Frames 1273 of 3584 done
# Frames 1274 of 3584 done
# Frames 1275 of 3584 done
# Frames 1276 of 3584 done
# Frames 1277 of 3584 done
# Frames 1278 of 3584 done
# Frames 1279 of 3584 done
# Frames 1280 of 3584 done
# Frames 1281 of 3584 done
# Frames 1282 of 3584 done
# Frames 1283 of 3584 done
# Frames 1284 of 3584 done
# Frames 1285 of 3584 done
# Frames 1286 of 3584 done
# Frames 1287 of 3584 done
# Frames 1288 of 3584 done
# Frames 1289 of 3584 done
# Frames 1290 of 3584 done
# Frames 1291 of 3584 done
# Frames 1292 of 3584 done
# Frames 1293 of 3584 done
# Frames 1294 of 3584 done
# Frames 1295 of 3584 done
# Frames 1296 of 3584 done
# Frames 1297 of 3584 done
# Frames 1298 of 3584 done
# Frames 1299 of 3584 done
# Frames 1300 of 3584 done
# Frames 1301 of 3584 done
# Frames 1302 of 3584 done
# Frames 1303 of 3584 done
# Frames 1304 of 3584 done
# Frames 1305 of 3584 done
# Frames 1306 of 3584 done
# Frames 1307 of 3584 done
# Frames 1308 of 3584 done
# Frames 1309 of 3584 done
# Frames 1310 of 3584 done
# Frames 1311 of 3584 done
# Frames 1312 of 3584 done
# Frames 1313 of 3584 done
# Frames 1314 of 3584 done
# Frames 1315 of 3584 done
# Frames 1316 of 3584 done
# Frames 1317 of 3584 done
# Frames 1318 of 3584 done
# Frames 1319 of 3584 done
# Frames 1320 of 3584 done
# Frames 1321 of 3584 done
# Frames 1322 of 3584 done
# Frames 1323 of 3584 done
# Frames 1324 of 3584 done
# Frames 1325 of 3584 done
# Frames 1326 of 3584 done
# Frames 1327 of 3584 done
# Frames 1328 of 3584 done
# Frames 1329 of 3584 done
# Frames 1330 of 3584 done
# Frames 1331 of 3584 done
# Frames 1332 of 3584 done
# Frames 1333 of 3584 done
# Frames 1334 of 3584 done
# Frames 1335 of 3584 done
# Frames 1336 of 3584 done
# Frames 1337 of 3584 done
# Frames 1338 of 3584 done
# Frames 1339 of 3584 done
# Frames 1340 of 3584 done
# Frames 1341 of 3584 done
# Frames 1342 of 3584 done
# Frames 1343 of 3584 done
# Frames 1344 of 3584 done
# Frames 1345 of 3584 done
# Frames 1346 of 3584 done
# Frames 1347 of 3584 done
# Frames 1348 of 3584 done
# Frames 1349 of 3584 done
# Frames 1350 of 3584 done
# Frames 1351 of 3584 done
# Frames 1352 of 3584 done
# Frames 1353 of 3584 done
# Frames 1354 of 3584 done
# Frames 1355 of 3584 done
# Frames 1356 of 3584 done
# Frames 1357 of 3584 done
# Frames 1358 of 3584 done
# Frames 1359 of 3584 done
# Frames 1360 of 3584 done
# Frames 1361 of 3584 done
# Frames 1362 of 3584 done
# Frames 1363 of 3584 done
# Frames 1364 of 3584 done
# Frames 1365 of 3584 done
# Frames 1366 of 3584 done
# Frames 1367 of 3584 done
# Frames 1368 of 3584 done
# Frames 1369 of 3584 done
# Frames 1370 of 3584 done
# Frames 1371 of 3584 done
# Frames 1372 of 3584 done
# Frames 1373 of 3584 done
# Frames 1374 of 3584 done
# Frames 1375 of 3584 done
# Frames 1376 of 3584 done
# Frames 1377 of 3584 done
# Frames 1378 of 3584 done
# Frames 1379 of 3584 done
# Frames 1380 of 3584 done
# Frames 1381 of 3584 done
# Frames 1382 of 3584 done
# Frames 1383 of 3584 done
# Frames 1384 of 3584 done
# Frames 1385 of 3584 done
# Frames 1386 of 3584 done
# Frames 1387 of 3584 done
# Frames 1388 of 3584 done
# Frames 1389 of 3584 done
# Frames 1390 of 3584 done
# Frames 1391 of 3584 done
# Frames 1392 of 3584 done
# Frames 1393 of 3584 done
# Frames 1394 of 3584 done
# Frames 1395 of 3584 done
# Frames 1396 of 3584 done
# Frames 1397 of 3584 done
# Frames 1398 of 3584 done
# Frames 1399 of 3584 done
# Frames 1400 of 3584 done
# Frames 1401 of 3584 done
# Frames 1402 of 3584 done
# Frames 1403 of 3584 done
# Frames 1404 of 3584 done
# Frames 1405 of 3584 done
# Frames 1406 of 3584 done
# Frames 1407 of 3584 done
# Frames 1408 of 3584 done
# Frames 1409 of 3584 done
# Frames 1410 of 3584 done
# Frames 1411 of 3584 done
# Frames 1412 of 3584 done
# Frames 1413 of 3584 done
# Frames 1414 of 3584 done
# Frames 1415 of 3584 done
# Frames 1416 of 3584 done
# Frames 1417 of 3584 done
# Frames 1418 of 3584 done
# Frames 1419 of 3584 done
# Frames 1420 of 3584 done
# Frames 1421 of 3584 done
# Frames 1422 of 3584 done
# Frames 1423 of 3584 done
# Frames 1424 of 3584 done
# Frames 1425 of 3584 done
# Frames 1426 of 3584 done
# Frames 1427 of 3584 done
# Frames 1428 of 3584 done
# Frames 1429 of 3584 done
# Frames 1430 of 3584 done
# Frames 1431 of 3584 done
# Frames 1432 of 3584 done
# Frames 1433 of 3584 done
# Frames 1434 of 3584 done
# Frames 1435 of 3584 done
# Frames 1436 of 3584 done
# Frames 1437 of 3584 done
# Frames 1438 of 3584 done
# Frames 1439 of 3584 done
# Frames 1440 of 3584 done
# Frames 1441 of 3584 done
# Frames 1442 of 3584 done
# Frames 1443 of 3584 done
# Frames 1444 of 3584 done
# Frames 1445 of 3584 done
# Frames 1446 of 3584 done
# Frames 1447 of 3584 done
# Frames 1448 of 3584 done
# Frames 1449 of 3584 done
# Frames 1450 of 3584 done
# Frames 1451 of 3584 done
# Frames 1452 of 3584 done
# Frames 1453 of 3584 done
# Frames 1454 of 3584 done
# Frames 1455 of 3584 done
# Frames 1456 of 3584 done
# Frames 1457 of 3584 done
# Frames 1458 of 3584 done
# Frames 1459 of 3584 done
# Frames 1460 of 3584 done
# Frames 1461 of 3584 done
# Frames 1462 of 3584 done
# Frames 1463 of 3584 done
# Frames 1464 of 3584 done
# Frames 1465 of 3584 done
# Frames 1466 of 3584 done
# Frames 1467 of 3584 done
# Frames 1468 of 3584 done
# Frames 1469 of 3584 done
# Frames 1470 of 3584 done
# Frames 1471 of 3584 done
# Frames 1472 of 3584 done
# Frames 1473 of 3584 done
# Frames 1474 of 3584 done
# Frames 1475 of 3584 done
# Frames 1476 of 3584 done
# Frames 1477 of 3584 done
# Frames 1478 of 3584 done
# Frames 1479 of 3584 done
# Frames 1480 of 3584 done
# Frames 1481 of 3584 done
# Frames 1482 of 3584 done
# Frames 1483 of 3584 done
# Frames 1484 of 3584 done
# Frames 1485 of 3584 done
# Frames 1486 of 3584 done
# Frames 1487 of 3584 done
# Frames 1488 of 3584 done
# Frames 1489 of 3584 done
# Frames 1490 of 3584 done
# Frames 1491 of 3584 done
# Frames 1492 of 3584 done
# Frames 1493 of 3584 done
# Frames 1494 of 3584 done
# Frames 1495 of 3584 done
# Frames 1496 of 3584 done
# Frames 1497 of 3584 done
# Frames 1498 of 3584 done
# Frames 1499 of 3584 done
# Frames 1500 of 3584 done
# Frames 1501 of 3584 done
# Frames 1502 of 3584 done
# Frames 1503 of 3584 done
# Frames 1504 of 3584 done
# Frames 1505 of 3584 done
# Frames 1506 of 3584 done
# Frames 1507 of 3584 done
# Frames 1508 of 3584 done
# Frames 1509 of 3584 done
# Frames 1510 of 3584 done
# Frames 1511 of 3584 done
# Frames 1512 of 3584 done
# Frames 1513 of 3584 done
# Frames 1514 of 3584 done
# Frames 1515 of 3584 done
# Frames 1516 of 3584 done
# Frames 1517 of 3584 done
# Frames 1518 of 3584 done
# Frames 1519 of 3584 done
# Frames 1520 of 3584 done
# Frames 1521 of 3584 done
# Frames 1522 of 3584 done
# Frames 1523 of 3584 done
# Frames 1524 of 3584 done
# Frames 1525 of 3584 done
# Frames 1526 of 3584 done
# Frames 1527 of 3584 done
# Frames 1528 of 3584 done
# Frames 1529 of 3584 done
# Frames 1530 of 3584 done
# Frames 1531 of 3584 done
# Frames 1532 of 3584 done
# Frames 1533 of 3584 done
# Frames 1534 of 3584 done
# Frames 1535 of 3584 done
# Frames 1536 of 3584 done
# Frames 1537 of 3584 done
# Frames 1538 of 3584 done
# Frames 1539 of 3584 done
# Frames 1540 of 3584 done
# Frames 1541 of 3584 done
# Frames 1542 of 3584 done
# Frames 1543 of 3584 done
# Frames 1544 of 3584 done
# Frames 1545 of 3584 done
# Frames 1546 of 3584 done
# Frames 1547 of 3584 done
# Frames 1548 of 3584 done
# Frames 1549 of 3584 done
# Frames 1550 of 3584 done
# Frames 1551 of 3584 done
# Frames 1552 of 3584 done
# Frames 1553 of 3584 done
# Frames 1554 of 3584 done
# Frames 1555 of 3584 done
# Frames 1556 of 3584 done
# Frames 1557 of 3584 done
# Frames 1558 of 3584 done
# Frames 1559 of 3584 done
# Frames 1560 of 3584 done
# Frames 1561 of 3584 done
# Frames 1562 of 3584 done
# Frames 1563 of 3584 done
# Frames 1564 of 3584 done
# Frames 1565 of 3584 done
# Frames 1566 of 3584 done
# Frames 1567 of 3584 done
# Frames 1568 of 3584 done
# Frames 1569 of 3584 done
# Frames 1570 of 3584 done
# Frames 1571 of 3584 done
# Frames 1572 of 3584 done
# Frames 1573 of 3584 done
# Frames 1574 of 3584 done
# Frames 1575 of 3584 done
# Frames 1576 of 3584 done
# Frames 1577 of 3584 done
# Frames 1578 of 3584 done
# Frames 1579 of 3584 done
# Frames 1580 of 3584 done
# Frames 1581 of 3584 done
# Frames 1582 of 3584 done
# Frames 1583 of 3584 done
# Frames 1584 of 3584 done
# Frames 1585 of 3584 done
# Frames 1586 of 3584 done
# Frames 1587 of 3584 done
# Frames 1588 of 3584 done
# Frames 1589 of 3584 done
# Frames 1590 of 3584 done
# Frames 1591 of 3584 done
# Frames 1592 of 3584 done
# Frames 1593 of 3584 done
# Frames 1594 of 3584 done
# Frames 1595 of 3584 done
# Frames 1596 of 3584 done
# Frames 1597 of 3584 done
# Frames 1598 of 3584 done
# Frames 1599 of 3584 done
# Frames 1600 of 3584 done
# Frames 1601 of 3584 done
# Frames 1602 of 3584 done
# Frames 1603 of 3584 done
# Frames 1604 of 3584 done
# Frames 1605 of 3584 done
# Frames 1606 of 3584 done
# Frames 1607 of 3584 done
# Frames 1608 of 3584 done
# Frames 1609 of 3584 done
# Frames 1610 of 3584 done
# Frames 1611 of 3584 done
# Frames 1612 of 3584 done
# Frames 1613 of 3584 done
# Frames 1614 of 3584 done
# Frames 1615 of 3584 done
# Frames 1616 of 3584 done
# Frames 1617 of 3584 done
# Frames 1618 of 3584 done
# Frames 1619 of 3584 done
# Frames 1620 of 3584 done
# Frames 1621 of 3584 done
# Frames 1622 of 3584 done
# Frames 1623 of 3584 done
# Frames 1624 of 3584 done
# Frames 1625 of 3584 done
# Frames 1626 of 3584 done
# Frames 1627 of 3584 done
# Frames 1628 of 3584 done
# Frames 1629 of 3584 done
# Frames 1630 of 3584 done
# Frames 1631 of 3584 done
# Frames 1632 of 3584 done
# Frames 1633 of 3584 done
# Frames 1634 of 3584 done
# Frames 1635 of 3584 done
# Frames 1636 of 3584 done
# Frames 1637 of 3584 done
# Frames 1638 of 3584 done
# Frames 1639 of 3584 done
# Frames 1640 of 3584 done
# Frames 1641 of 3584 done
# Frames 1642 of 3584 done
# Frames 1643 of 3584 done
# Frames 1644 of 3584 done
# Frames 1645 of 3584 done
# Frames 1646 of 3584 done
# Frames 1647 of 3584 done
# Frames 1648 of 3584 done
# Frames 1649 of 3584 done
# Frames 1650 of 3584 done
# Frames 1651 of 3584 done
# Frames 1652 of 3584 done
# Frames 1653 of 3584 done
# Frames 1654 of 3584 done
# Frames 1655 of 3584 done
# Frames 1656 of 3584 done
# Frames 1657 of 3584 done
# Frames 1658 of 3584 done
# Frames 1659 of 3584 done
# Frames 1660 of 3584 done
# Frames 1661 of 3584 done
# Frames 1662 of 3584 done
# Frames 1663 of 3584 done
# Frames 1664 of 3584 done
# Frames 1665 of 3584 done
# Frames 1666 of 3584 done
# Frames 1667 of 3584 done
# Frames 1668 of 3584 done
# Frames 1669 of 3584 done
# Frames 1670 of 3584 done
# Frames 1671 of 3584 done
# Frames 1672 of 3584 done
# Frames 1673 of 3584 done
# Frames 1674 of 3584 done
# Frames 1675 of 3584 done
# Frames 1676 of 3584 done
# Frames 1677 of 3584 done
# Frames 1678 of 3584 done
# Frames 1679 of 3584 done
# Frames 1680 of 3584 done
# Frames 1681 of 3584 done
# Frames 1682 of 3584 done
# Frames 1683 of 3584 done
# Frames 1684 of 3584 done
# Frames 1685 of 3584 done
# Frames 1686 of 3584 done
# Frames 1687 of 3584 done
# Frames 1688 of 3584 done
# Frames 1689 of 3584 done
# Frames 1690 of 3584 done
# Frames 1691 of 3584 done
# Frames 1692 of 3584 done
# Frames 1693 of 3584 done
# Frames 1694 of 3584 done
# Frames 1695 of 3584 done
# Frames 1696 of 3584 done
# Frames 1697 of 3584 done
# Frames 1698 of 3584 done
# Frames 1699 of 3584 done
# Frames 1700 of 3584 done
# Frames 1701 of 3584 done
# Frames 1702 of 3584 done
# Frames 1703 of 3584 done
# Frames 1704 of 3584 done
# Frames 1705 of 3584 done
# Frames 1706 of 3584 done
# Frames 1707 of 3584 done
# Frames 1708 of 3584 done
# Frames 1709 of 3584 done
# Frames 1710 of 3584 done
# Frames 1711 of 3584 done
# Frames 1712 of 3584 done
# Frames 1713 of 3584 done
# Frames 1714 of 3584 done
# Frames 1715 of 3584 done
# Frames 1716 of 3584 done
# Frames 1717 of 3584 done
# Frames 1718 of 3584 done
# Frames 1719 of 3584 done
# Frames 1720 of 3584 done
# Frames 1721 of 3584 done
# Frames 1722 of 3584 done
# Frames 1723 of 3584 done
# Frames 1724 of 3584 done
# Frames 1725 of 3584 done
# Frames 1726 of 3584 done
# Frames 1727 of 3584 done
# Frames 1728 of 3584 done
# Frames 1729 of 3584 done
# Frames 1730 of 3584 done
# Frames 1731 of 3584 done
# Frames 1732 of 3584 done
# Frames 1733 of 3584 done
# Frames 1734 of 3584 done
# Frames 1735 of 3584 done
# Frames 1736 of 3584 done
# Frames 1737 of 3584 done
# Frames 1738 of 3584 done
# Frames 1739 of 3584 done
# Frames 1740 of 3584 done
# Frames 1741 of 3584 done
# Frames 1742 of 3584 done
# Frames 1743 of 3584 done
# Frames 1744 of 3584 done
# Frames 1745 of 3584 done
# Frames 1746 of 3584 done
# Frames 1747 of 3584 done
# Frames 1748 of 3584 done
# Frames 1749 of 3584 done
# Frames 1750 of 3584 done
# Frames 1751 of 3584 done
# Frames 1752 of 3584 done
# Frames 1753 of 3584 done
# Frames 1754 of 3584 done
# Frames 1755 of 3584 done
# Frames 1756 of 3584 done
# Frames 1757 of 3584 done
# Frames 1758 of 3584 done
# Frames 1759 of 3584 done
# Frames 1760 of 3584 done
# Frames 1761 of 3584 done
# Frames 1762 of 3584 done
# Frames 1763 of 3584 done
# Frames 1764 of 3584 done
# Frames 1765 of 3584 done
# Frames 1766 of 3584 done
# Frames 1767 of 3584 done
# Frames 1768 of 3584 done
# Frames 1769 of 3584 done
# Frames 1770 of 3584 done
# Frames 1771 of 3584 done
# Frames 1772 of 3584 done
# Frames 1773 of 3584 done
# Frames 1774 of 3584 done
# Frames 1775 of 3584 done
# Frames 1776 of 3584 done
# Frames 1777 of 3584 done
# Frames 1778 of 3584 done
# Frames 1779 of 3584 done
# Frames 1780 of 3584 done
# Frames 1781 of 3584 done
# Frames 1782 of 3584 done
# Frames 1783 of 3584 done
# Frames 1784 of 3584 done
# Frames 1785 of 3584 done
# Frames 1786 of 3584 done
# Frames 1787 of 3584 done
# Frames 1788 of 3584 done
# Frames 1789 of 3584 done
# Frames 1790 of 3584 done
# Frames 1894 of 3584 done
# Frames 1895 of 3584 done
# Frames 1896 of 3584 done
# Frames 1897 of 3584 done
# Frames 1898 of 3584 done
# Frames 1899 of 3584 done
# Frames 1900 of 3584 done
# Frames 1901 of 3584 done
# Frames 1902 of 3584 done
# Frames 1903 of 3584 done
# Frames 1904 of 3584 done
# Frames 1905 of 3584 done
# Frames 1906 of 3584 done
# Frames 1907 of 3584 done
# Frames 1908 of 3584 done
# Frames 1909 of 3584 done
# Frames 1910 of 3584 done
# Frames 1911 of 3584 done
# Frames 1912 of 3584 done
# Frames 1913 of 3584 done
# Frames 1914 of 3584 done
# Frames 1915 of 3584 done
# Frames 1916 of 3584 done
# Frames 1917 of 3584 done
# Frames 1918 of 3584 done
# Frames 1919 of 3584 done
# Frames 1920 of 3584 done
# Frames 1921 of 3584 done
# Frames 1922 of 3584 done
# Frames 1923 of 3584 done
# Frames 1924 of 3584 done
# Frames 1925 of 3584 done
# Frames 1926 of 3584 done
# Frames 1927 of 3584 done
# Frames 1928 of 3584 done
# Frames 1929 of 3584 done
# Frames 1930 of 3584 done
# Frames 1931 of 3584 done
# Frames 1932 of 3584 done
# Frames 1933 of 3584 done
# Frames 1934 of 3584 done
# Frames 1935 of 3584 done
# Frames 1936 of 3584 done
# Frames 1937 of 3584 done
# Frames 1938 of 3584 done
# Frames 1939 of 3584 done
# Frames 1940 of 3584 done
# Frames 1941 of 3584 done
# Frames 1942 of 3584 done
# Frames 1943 of 3584 done
# Frames 1944 of 3584 done
# Frames 1945 of 3584 done
# Frames 1946 of 3584 done
# Frames 1947 of 3584 done
# Frames 1948 of 3584 done
# Frames 1949 of 3584 done
# Frames 1950 of 3584 done
# Frames 1951 of 3584 done
# Frames 1952 of 3584 done
# Frames 1953 of 3584 done
# Frames 1954 of 3584 done
# Frames 1955 of 3584 done
# Frames 1956 of 3584 done
# Frames 1957 of 3584 done
# ...
# Done pair 3374 of 3583 (avg time: 0.0471271387736 secs --- remaining: 0:9)
# Done pair 3375 of 3583 (avg time: 0.0471269790595 secs --- remaining: 0:9)
# Done pair 3376 of 3583 (avg time: 0.0471268452093 secs --- remaining: 0:9)
# Done pair 3377 of 3583 (avg time: 0.04712668243 secs --- remaining: 0:9)
# Done pair 3378 of 3583 (avg time: 0.0471266049822 secs --- remaining: 0:9)
# Done pair 3379 of 3583 (avg time: 0.0471264683989 secs --- remaining: 0:9)
# Done pair 3380 of 3583 (avg time: 0.0471263003046 secs --- remaining: 0:9)
# Done pair 3381 of 3583 (avg time: 0.0471261393594 secs --- remaining: 0:9)
# Done pair 3382 of 3583 (avg time: 0.04712595342 secs --- remaining: 0:9)
# Done pair 3383 of 3583 (avg time: 0.0471257601928 secs --- remaining: 0:9)
# Done pair 3384 of 3583 (avg time: 0.0471256199756 secs --- remaining: 0:9)
# Done pair 3385 of 3583 (avg time: 0.0471255087106 secs --- remaining: 0:9)
# Done pair 3386 of 3583 (avg time: 0.0471252877697 secs --- remaining: 0:9)
# Done pair 3387 of 3583 (avg time: 0.0471256418239 secs --- remaining: 0:9)
# Done pair 3571 of 3583 (avg time: 0.0471128994914 secs --- remaining: 0:0)
# Done pair 3572 of 3583 (avg time: 0.0471128698093 secs --- remaining: 0:0)
# Done pair 3573 of 3583 (avg time: 0.0471127240699 secs --- remaining: 0:0)
# Done pair 3574 of 3583 (avg time: 0.0471125954848 secs --- remaining: 0:0)
# Done pair 3575 of 3583 (avg time: 0.0471124765057 secs --- remaining: 0:0)
# Done pair 3576 of 3583 (avg time: 0.0471123950522 secs --- remaining: 0:0)
# Done pair 3577 of 3583 (avg time: 0.0471122451439 secs --- remaining: 0:0)
# Done pair 3578 of 3583 (avg time: 0.0471122953671 secs --- remaining: 0:0)
# Done pair 3579 of 3583 (avg time: 0.0471121502988 secs --- remaining: 0:0)
# Done pair 3580 of 3583 (avg time: 0.0471119050439 secs --- remaining: 0:0)
# Done pair 3581 of 3583 (avg time: 0.0471116329025 secs --- remaining: 0:0)
# Done pair 3582 of 3583 (avg time: 0.0471115741123 secs --- remaining: 0:0)
# Done pair 0 of 5 (avg time: 0.0454699993134 secs --- remaining: 0:0)
# Done pair 1 of 5 (avg time: 0.0457744598389 secs --- remaining: 0:0)
# Done pair 2 of 5 (avg time: 0.0461566448212 secs --- remaining: 0:0)
# Done pair 3 of 5 (avg time: 0.046355009079 secs --- remaining: 0:0)
# Done pair 4 of 5 (avg time: 0.0463995933533 secs --- remaining: 0:0)

# %%
def getTrainingData(goodPairsToUse, goodExamplesData, badPairsToUse, badExamplesData, saveLoc, labelMultiplier = 1) :  
    ### X has shape [featSize, numPairs]  
        
    X = np.concatenate((goodExamplesData[:, goodPairsToUse], badExamplesData[:, badPairsToUse]), axis=1)
    w = np.concatenate((np.zeros(len(goodPairsToUse)), labelMultiplier*np.ones(len(badPairsToUse)))).reshape((X.shape[-1], 1))
    sio.savemat(saveLoc, {"X":X, "w":w})
    
    return X, w

trainingExamplesLoc = dataPath + dataSet + "trainingExamplesForImageData"
featsSubset = arange(len(goodExamplesData[0]))
X, w = getTrainingData(arange(len(goodPairsIdxs.T)), np.array(goodExamplesData).T[featsSubset, :], arange(len(badPairsIdxs.T)),
                       np.array(badExamplesData).T[featsSubset, :], trainingExamplesLoc)

phiSaveLoc = dataPath + dataSet + "fittedPhiForImageDataUsingPsi.mat"

matlabCommand = "cd ~/PhD/MATLAB/; matlab -nosplash -nodesktop -nodisplay -r "
matlabCommand += "\"fitPsiForRegression '" + trainingExamplesLoc + "' '"
matlabCommand += phiSaveLoc + "'; exit;\""

stat, output = commands.getstatusoutput(matlabCommand)
stat /= 256

if stat == 10 :
    print "Error when saving result"
elif stat == 11 :
    print "Error when loading examples"
else :
    print "Optimization completed with status", stat
    
print output
# Out:
# Optimization completed with status 0
#
#                             < M A T L A B (R) >
#                   Copyright 1984-2014 The MathWorks, Inc.
#                    R2014b (8.4.0.150421) 64-bit (glnxa64)
#                              September 15, 2014
#
#
# To get started, type one of these: helpwin, helpdesk, or demo.
# For product information, visit www.mathworks.com.
#
# Loaded 3588 examples of size 400
# Warning: Struct field assignment overwrites a value with class "double". See
# MATLAB R14SP2 Release Notes, Assigning Nonstructure Variables As Structures
# Displays Warning, for details.]
# > In fitPsiForRegression at 52]
# f is 71332.9061 g size is 400
#  Iteration   FunEvals     Step Length    Function Val        Opt Cond
# newtonCG stopped on iteration 1 w/ residual 6.63422e+03
#          1          3     1.00000e+00     3.87644e+04     2.19337e+03
# newtonCG stopped on iteration 1 w/ residual 1.99825e+03
#          2          5     1.00000e+00     1.98822e+04     6.36264e+02
# newtonCG stopped on iteration 1 w/ residual 7.30417e+02
#          3          7     1.00000e+00     1.04075e+04     1.92897e+02
# newtonCG stopped on iteration 1 w/ residual 2.93397e+02
#          4          9     1.00000e+00     5.91376e+03     5.86068e+01
# newtonCG stopped on iteration 1 w/ residual 1.05963e+02
#          5         11     1.00000e+00     3.88422e+03     1.85784e+01
# newtonCG stopped on iteration 1 w/ residual 2.57004e+01
#          6         13     1.00000e+00     3.14595e+03     5.55922e+00
# newtonCG stopped on iteration 1 w/ residual 5.26380e+00
#          7         15     1.00000e+00     2.98121e+03     1.32920e+00
# newtonCG stopped on iteration 1 w/ residual 1.20709e+00
#          8         17     1.00000e+00     2.96744e+03     1.86798e-01
# newtonCG stopped on iteration 1 w/ residual 3.60416e-01
#          9         19     1.00000e+00     2.96718e+03     4.97189e-02
# newtonCG stopped on iteration 1 w/ residual 9.74102e-02
#         10         21     1.00000e+00     2.96717e+03     1.04599e-02
# newtonCG stopped on iteration 1 w/ residual 2.47526e-02
#         11         23     1.00000e+00     2.96717e+03     3.53041e-03
# newtonCG stopped on iteration 2 w/ residual 1.64822e-04
#         12         26     1.00000e+00     2.96717e+03     3.84928e-05
# newtonCG stopped on iteration 2 w/ residual 6.60187e-07
#         13         29     1.00000e+00     2.96717e+03     1.06302e-07
# Optimality Condition below optTol
# Exit flag of optimization is 1
# Saved phi_MAP as /media/ilisescu/Data1/PhD/data/wave1/fittedPhiForImageDataUsingPsi.mat

# %%
phiSaveLoc = dataPath + dataSet + "fittedPhiForImageDataUsingPsi.mat"
copyanything(sequence[DICT_MASK_LOCATION], tmpLoc)
regressedWeights = sio.loadmat(phiSaveLoc)['phi_MAP']

numFrames = len(sequence[DICT_BBOXES])
if np.prod(bottomRight-topLeft)*3*8/1000000.0*len(sequence[DICT_BBOXES]) > 15000 :
    numBlocks = 4
else :
    numBlocks = 1
blockSize = numFrames/numBlocks
distMat = np.zeros([numFrames, numFrames])
print "blocks", numBlocks

# for i in xrange(0, numBlocks) :
i = 0

# f1s = np.zeros(np.hstack([bottomRight[0]-topLeft[0], bottomRight[1]-topLeft[1], 3, blockSize]), dtype=np.float64)
# for idx, frame in enumerate(np.sort(glob.glob(tmpLoc+"frame-0*.png"))[i*blockSize:i*blockSize+blockSize]) :
#     img = np.array(Image.open(frame), dtype=np.float64)[topLeft[0]:bottomRight[0], topLeft[1]:bottomRight[1], :]
#     alpha = img[:, :, -1]/255.0
#     f1s[:, :, :, idx] = (img[:, :, :-1]/255.0)*np.reshape(alpha, (alpha.shape[0], alpha.shape[1], 1))

f1s = np.zeros(np.hstack([bottomRight[0]-topLeft[0], bottomRight[1]-topLeft[1], blockSize]), dtype=np.uint8)
for idx, frame in enumerate(np.sort(glob.glob(tmpLoc+"frame-0*.png"))[i*blockSize:i*blockSize+blockSize]) :
    img = np.array(Image.open(frame), dtype=np.uint8)[topLeft[0]:bottomRight[0], topLeft[1]:bottomRight[1], :]
#     alpha = img[:, :, -1]/255.0
#     f1s[:, :, :, idx] = np.array((img[:, :, :-1]/255.0)*np.reshape(alpha, (alpha.shape[0], alpha.shape[1], 1)), dtype=np.uint8)
    f1s[:, :, idx] = cv2.cvtColor(img, cv2.COLOR_RGBA2GRAY)
    
    if np.mod(idx, 200) == 0 :
        print "loaded", idx; sys.stdout.flush()

print "loaded frames, block i=", i; sys.stdout.flush()

# data1 = np.reshape(f1s, [np.prod(f1s.shape[0:-1]), f1s.shape[-1]]).T
# distMat[i*blockSize:i*blockSize+blockSize, i*blockSize:i*blockSize+blockSize] = ssd(data1)
print "computed distance"; sys.stdout.flush()
# Out:
# blocks 1
# loaded
#  0
# loaded 200
# loaded 400
# loaded 600
# loaded 800
# loaded 1000
# loaded 1200
# loaded 1400
# loaded 1600
# loaded 1800
# loaded 2000
# loaded 2200
# loaded 2400
# loaded 2600
# loaded 2800
# loaded 3000
# loaded 3200
# loaded 3400
# loaded frames, block i= 0
# computed distance

# %%
### computes subsets of the full feature set
# frameSubset = f1s[:, :, pairsToCompute[:30000, 0]]
# pairsToCompute = goodPairsIdxs.T
# pairsToCompute = badPairsIdxs.T
pairsToCompute = np.argwhere(np.triu(np.ones((numFrames, numFrames)), k=1))
numSubsets = 8 #1
subsetSize = len(pairsToCompute)/numSubsets
gridStencils = cgf.stencil2D(gridSize[0], gridSize[1], [imageSize[0], imageSize[1], 3])

for i in arange(numSubsets)[6:] :
    startTime = time.time()
    feats = np.zeros((subsetSize, len(gridStencils)))

    pairsIdxs1 = pairsToCompute[subsetSize*i:subsetSize*(i+1), 0].repeat(len(gridStencils[0][0]))
    pairsIdxs2 = pairsToCompute[subsetSize*i:subsetSize*(i+1), 1].repeat(len(gridStencils[0][0]))
    
    feats[:, :270] = np.load("tmpfeats.npy")

    avgTime = 0.0
    for j, stencil in enumerate(gridStencils[270:]) :
        t = time.time()
        ## add SSD to feature vector
        stencilRowIdxs = stencil[0].reshape((1, len(stencil[0]))).repeat(subsetSize, axis=0).flatten()
        stencilColIdxs = stencil[1].reshape((1, len(stencil[1]))).repeat(subsetSize, axis=0).flatten()
        
        
        feats[:, j] = np.average((f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs1].reshape((subsetSize, len(stencil[0])))/255.0-
                                  f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs2].reshape((subsetSize, len(stencil[0])))/255.0)**2, axis=1)
        
#         feats = np.concatenate((feats, [np.average((frame1[stencil]/255.0-frame2[stencil]/255.0)**2)]))

        avgTime = (avgTime*j + time.time()-t)/(j+1)
        remainingTime = avgTime*(len(gridStencils)-j-1)/60.0
        sys.stdout.write('\r' + "Done stencil " + np.string_(j) + " of " + np.string_(len(gridStencils)) +
                         " (avg time: " + np.string_(avgTime) + " secs --- remaining: " +
                         np.string_(int(np.floor(remainingTime))) + ":" + np.string_(int((remainingTime - np.floor(remainingTime))*60)) + ")")
        sys.stdout.flush()
        
    np.save("/".join(sequence[DICT_SEQUENCE_LOCATION].split("/")[:-1])+"/"+"features-"+sequence[DICT_SEQUENCE_NAME]+"-subset"+np.string_(i)+".npy", feats)

    # print (f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs].reshape((subsetSize, len(stencil[0])))/255.0).shape
    print 
    print "done subset", i, "in", time.time() - startTime, "secs"
# Out:
# Done stencil 0 of 400 (avg time: 16.6068949699 secs --- remaining: 110:26)
# Done stencil 1 of 400 (avg time: 16.9100115299 secs --- remaining: 112:10)
# Done stencil 2 of 400 (avg time: 16.6714266936 secs --- remaining: 110:18)
# Done stencil 3 of 400 (avg time: 16.567222774 secs --- remaining: 109:20)
# Done stencil 4 of 400 (avg time: 16.4972982407 secs --- remaining: 108:36)
# Done stencil 5 of 400 (avg time: 16.4443338712 secs --- remaining: 107:59)
# Done stencil 6 of 400 (avg time: 16.4538323198 secs --- remaining: 107:46)
# Done stencil 7 of 400 (avg time: 16.4628996551 secs --- remaining: 107:33)
# Done stencil 8 of 400 (avg time: 16.4357095824 secs --- remaining: 107:6)
# Done stencil 9 of 400 (avg time: 16.4165242195 secs --- remaining: 106:42)
# Done stencil 10 of 400 (avg time: 16.4053516605 secs --- remaining: 106:21)
# Done stencil 11 of 400 (avg time: 16.3946254452 secs --- remaining: 106:1)
# Done stencil 12 of 400 (avg time: 16.3863019576 secs --- remaining: 105:41)
# Done stencil 13 of 400 (avg time: 16.3718858957 secs --- remaining: 105:19)
# Done stencil 14 of 400 (avg time: 16.3621480942 secs --- remaining: 104:59)
# Done stencil 15 of 400 (avg time: 16.3471082747 secs --- remaining: 104:37)
# Done stencil 16 of 400 (avg time: 16.3350299106 secs --- remaining: 104:16)
# Done stencil 17 of 400 (avg time: 16.3345621427 secs --- remaining: 103:59)
# Done stencil 18 of 400 (avg time: 16.3263101452 secs --- remaining: 103:40)
# Done stencil 19 of 400 (avg time: 16.3165663958 secs --- remaining: 103:20)
# Done stencil 20 of 400 (avg time: 16.3090288071 secs --- remaining: 103:1)
# Done stencil 21 of 400 (avg time: 16.303237319 secs --- remaining: 102:42)
# Done stencil 22 of 400 (avg time: 16.3068184853 secs --- remaining: 102:27)
# Done stencil 23 of 400 (avg time: 16.3027554154 secs --- remaining: 102:9)
# Done stencil 24 of 400 (avg time: 16.2957881546 secs --- remaining: 101:50)
# Done stencil 25 of 400 (avg time: 16.2979689561 secs --- remaining: 101:35)
# Done stencil 26 of 400 (avg time: 16.3074383647 secs --- remaining: 101:22)
# Done stencil 27 of 400 (avg time: 16.3124453511 secs --- remaining: 101:8)
# Done stencil 28 of 400 (avg time: 16.318757756 secs --- remaining: 100:54)
# Done stencil 29 of 400 (avg time: 16.3272420963 secs --- remaining: 100:41)
# Done stencil 30 of 400 (avg time: 16.3350089981 secs --- remaining: 100:27)

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-0efac3ff4584> in <module>()
#      24
#      25         feats[:, j] = np.average((f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs1].reshape((subsetSize, len(stencil[0])))/255.0-
# ---> 26                                   f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs2].reshape((subsetSize, len(stencil[0])))/255.0)**2, axis=1)
#      27
#      28 #         feats = np.concatenate((feats, [np.average((frame1[stencil]/255.0-frame2[stencil]/255.0)**2)]))
#
# KeyboardInterrupt:

# %%
np.save("tmpfeats.npy", feats[:, :270])

# %%
distMat = np.zeros((numFrames, numFrames))
for i, subsetLoc in enumerate(np.sort(glob.glob("/".join(sequence[DICT_SEQUENCE_LOCATION].split("/")[:-1])+"/"+"features-*.npy"))) :
    distMat[pairsToCompute[subsetSize*i:subsetSize*(i+1), 0],
            pairsToCompute[subsetSize*i:subsetSize*(i+1), 1]] = np.dot(np.load(subsetLoc), regressedWeights).flatten()
    print subsetLoc
distMat[pairsToCompute[:, 1], pairsToCompute[:, 0]] = distMat[pairsToCompute[:, 0], pairsToCompute[:, 1]]
distMat[arange(numFrames), arange(numFrames)] = np.max(distMat)
gwv.showCustomGraph(distMat)
# Out:
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset0.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset1.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset2.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset3.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset4.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset5.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset6.npy
# /media/ilisescu/Data1/PhD/data/wave3/features-james3-subset7.npy

# %%
np.save("/".join(sequence[DICT_SEQUENCE_LOCATION].split("/")[:-1])+"/"+sequence[DICT_SEQUENCE_NAME]+"-learned_distMat.npy", distMat)

# %%
# print feats.shape
# print np.array(goodExamplesData).shape
# print np.argwhere(feats-np.array(goodExamplesData) != 0.0)
# print np.argwhere(feats != 0.0)
# print np.argwhere(np.array(goodExamplesData) != 0.0)
# print np.argwhere(np.argwhere(feats != 0.0) - np.argwhere(np.array(goodExamplesData) != 0.0) != 0.0)
print feats.shape
print np.array(badExamplesData).shape
print np.argwhere(feats-np.array(badExamplesData) != 0.0)
print np.argwhere(feats != 0.0)
print np.argwhere(np.array(badExamplesData) != 0.0)
print np.argwhere(np.argwhere(feats != 0.0) - np.argwhere(np.array(badExamplesData) != 0.0) != 0.0)
# Out:
# (3, 400)
# (3, 400)
# []
# [[  0   6]
#  [  0   7]
#  [  0   8]
#  ...,
#  [  2 393]
#  [  2 394]
#  [  2 395]]
# [[  0   6]
#  [  0   7]
#  [  0   8]
#  ...,
#  [  2 393]
#  [  2 394]
#  [  2 395]]
# []

# %%
subsetSize = 2
stencil = gridStencils[87]
print pairsToCompute[:2, :]
stencilRowIdxs = stencil[0].reshape((1, len(stencil[0]))).repeat(subsetSize, axis=0).flatten()
stencilColIdxs = stencil[1].reshape((1, len(stencil[1]))).repeat(subsetSize, axis=0).flatten()
pairsIdxs = pairsToCompute[:subsetSize, 1].repeat(len(stencil[0]))
print f1s[stencilRowIdxs, stencilColIdxs, pairsIdxs].reshape((subsetSize, len(stencil[0])))
# Out:
# [[156 163 165 168 172 174 176 178 178 179 180 182 182 165 166 170 172 174
#   176 177 179 179 180 181 181 182 170 170 172 173 176 178 178 179 180 180
#   181 182 182 173 173 173 175 176 178 179 180 181 181 182 182 183 174 175
#   175 175 177 177 178 179 180 180 181 181 182 174 175 176 175 177 177 178
#   179 180 180 181 181 182 175 175 176 176 177 177 178 179 180 180 181 181
#   182 175 175 176 176 177 177 178 179 180 180 181 181 182 176 176 177 177
#   178 178 179 179 180 180 180 181 181 175 175 176 176 177 177 179 179 180
#   180 179 180 180 175 175 176 176 177 177 179 179 180 180 179 180 180 175
#   175 176 176 177 177 178 178 180 180 179 180 180 174 175 175 176 176 176
#   177 177 179 179 179 179 180 174 174 175 175 177 177 177 177 178 179 178
#   179 179 174 175 175 176 177 177 177 177 178 179 179 179 180]
#  [159 159 164 167 172 175 176 177 178 179 179 180 181 166 168 170 172 174
#   177 177 177 178 179 180 181 181 168 170 171 173 175 177 178 178 179 180
#   180 181 181 171 173 173 175 176 178 178 178 179 180 180 180 181 173 174
#   175 176 177 179 179 179 180 181 181 181 181 175 176 175 175 176 178 178
#   179 179 180 180 180 181 175 176 175 175 176 178 178 179 179 180 180 180
#   180 174 175 175 175 176 178 178 179 180 181 180 180 180 174 175 175 175
#   176 178 178 179 180 181 180 180 180 175 175 175 175 176 177 177 178 179
#   180 180 180 180 175 175 175 175 176 177 177 178 179 180 180 180 180 175
#   175 175 175 176 177 177 178 179 180 180 180 180 175 175 175 175 176 177
#   177 178 179 180 180 180 180 175 175 176 176 177 177 178 179 179 179 180
#   180 180 175 176 176 176 177 177 178 179 179 179 180 180 180]]

# %%
print frameSubset[stencil[0], stencil[1], :].shape
# figure(); imshow(f1s[:, :, 2400])
# Out:
# (195, 30000)

# %%
gridStencils = cgf.stencil2D(gridSize[0], gridSize[1], [imageSize[0], imageSize[1], 3])
frame1 = f1s[:, :, :, 0]
for j, stencil in enumerate(gridStencils) :
    ## add SSD to feature vector
    print len(stencil[0])
    print frame1[:, :, 1][stencil].shape
#     feats = np.concatenate((feats, [np.average((frame1[stencil]/255.0-frame2[stencil]/255.0)**2)]))
# Out:
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)
# 195
# (195,)

# %%
# gwv.showCustomGraph(sio.loadmat(phiSaveLoc)["phi_MAP"].reshape(gridSize))
print "Weighted", np.sqrt(np.dot(X[:, -1].reshape((1, np.prod(gridSize))), sio.loadmat(phiSaveLoc)['phi_MAP'])) 
print "L2", np.sqrt(np.dot(X[:, -1].reshape((1, np.prod(gridSize))), np.ones_like(sio.loadmat(phiSaveLoc)['phi_MAP'])))
# Out:
# Weighted [[ 0.39329037]]
# L2 [[ 1.64377714]]

# %%
print "Weighted", np.sqrt(np.dot(X[:, 1].reshape((1, np.prod(gridSize))), sio.loadmat(phiSaveLoc)['phi_MAP'])) 
print "L2", np.sqrt(np.dot(X[:, 1].reshape((1, np.prod(gridSize))), np.ones_like(sio.loadmat(phiSaveLoc)['phi_MAP'])))
# Out:
# Weighted [[ 1.24317396]]
# L2 [[ 2.49034364]]
